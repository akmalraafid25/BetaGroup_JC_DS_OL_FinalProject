# %% [markdown]
# <div style="text-align: start; margin-bottom: 4px;">
#     <h1><b>Bank Marketing Campaign</h1>
#     <h4><b>Final Project</b><br>JCDSOL-18<br>by : Akmal Raafid Taufiqurrahman & Rikal Muhammad</h4>
# </div>

# %% [markdown]
# ---
# ## **Contents:**
#
# 1. Dataset Overview
#
# 2. Problem Statement
# 3. Data Understanding
# 4. Exploratory Data Analysis
# 5. Preprocessing
# 6. Methodology (Modeling/Analysis)
# 7. Conclusion and Recommendation

# %% [markdown]
# ---
# ## **Dataset Overview**
# #### **Konteks Dataset**
# Data yang digunakan dalam proyek ini berasal dari kampanye pemasaran langsung sebuah bank di **Portugal**, yang bertujuan untuk menawarkan produk deposito berjangka (term deposit) kepada nasabah. Dataset ini berisi informasi mengenai interaksi telemarketing yang dilakukan oleh agen bank kepada berbagai segmen nasabah, serta hasil akhir dari setiap kontak: apakah nasabah bersedia membuka deposito atau tidak.
#
# Dataset terdiri dari 41.188 baris data dan 21 kolom, mencakup informasi sebagai berikut:
#
# - Atribut Sosial-Ekonomi Nasabah<br><br>Contoh: age, job, marital, education, default, housing, loan<br><br>
# - Detail Kampanye Pemasaran<br><br>Contoh: contact (jenis kontak), month, day_of_week, duration, campaign (jumlah kontak selama kampanye), pdays, previous, poutcome (hasil kampanye sebelumnya)<br><br>
# - Indikator Ekonomi Makro saat Kampanye<br><br>Contoh: emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed<br><br>
# - Target (Label)<br>y: Apakah nasabah membuka deposito berjangka (yes atau no)
#
#
# Data ini telah digunakan secara luas dalam berbagai studi dan kompetisi data science, termasuk dalam publikasi Moro, Cortez & Rita (2014) yang menjadi referensi utama untuk pendekatan berbasis data dalam pengambilan keputusan pemasaran di industri perbankan.
#
# #### **Sumber Statement**
# Semua pernyataan berikut didasarkan pada dataset kampanye pemasaran bank Portugis yang digunakan dalam studi **Moro et al. (2014)**.
# <br>Data ini dikumpulkan antara **Mei 2008 hingga November 2010**, mencakup **41.188 interaksi**, dan sesuai dengan yang tersedia di Kaggle (https://www.kaggle.com/code/janiobachmann/bank-marketing-campaign-opening-a-term-deposit?scriptVersionId=11675860) ataupun UCI Repository (https://archive.ics.uci.edu/dataset/222/bank+marketing).
#
# Daftar sumber Refensi juga akan kami tuliskan pada akhir content.
#
# ---
# ## **Problem Statement**
# #### **Latar Belakang Masalah**
#
# Portugal diperkirakan memiliki `10,75 Juta` penduduk per tahun 2024 dengan kepadatan penduduk sekitar 116,6 jiwa per kilometer persegi, lebih tinggi dibandingkan dengan kebanyakan negara di uni eropa, dan sedikit melampaui rata-rata Uni Eropa sebesar 105,4 jiwa per kilometer persegi (273/mil persegi). Wilayah yang paling padat penduduknya adalah wilayah metropolitan Lisbon (yang berisi lebih dari seperempat populasi negara tersebut), wilayah metropolitan Porto dan pesisir Atlantik, sementara wilayah luas lainnya sangat jarang penduduknya. Jumlah penduduk negara ini hampir berlipat ganda selama abad ke-20, tetapi pola pertumbuhannya sangat tidak merata karena migrasi internal berskala besar dari pedesaan Utara ke kota-kota industri Lisbon dan Porto
#
# Dalam beberapa tahun terakhir, kondisi keuangan rumah tangga di Portugal menunjukkan tren yang positif, menciptakan peluang strategis bagi sektor perbankan untuk mengembangkan pendekatan pemasaran berbasis data. Berdasarkan analisis dari Corum Investments Portugal dan BA&N Research Unit, lebih dari 21% kekayaan bersih rumah tangga di Portugal saat ini disimpan dalam bentuk simpanan bank—menjadi proporsi tertinggi di kawasan euro. Hal ini mencerminkan preferensi masyarakat terhadap produk tabungan yang konservatif dan berisiko rendah.
#
# Setiap orang Portugal memiliki rata-rata €22.300 dalam bentuk simpanan bank (deposito dan tabungan), berdasarkan data ECB per Q1 2024 dengan jumlah total simpanan berjangka di bank untuk nasabah perorangan sekitar €100,704 miliar. Selama empat kuartal berturut-turut, pendapatan 'disposabel' rumah tangga terus mengalami pertumbuhan, mencapai hampir €189 miliar pada pertengahan 2024, dengan tingkat pertumbuhan tahunan sebesar 7,9%. Sementara pengeluaran konsumsi hanya tumbuh sebesar 4,6%, menyisakan ruang tabungan yang signifikan, yaitu sekitar €19 miliar. Kondisi ini menunjukkan bahwa kemampuan dan kecenderungan masyarakat untuk menabung meningkat, menciptakan peluang bagi bank untuk menawarkan produk-produk finansial yang lebih kompetitif dan tersegmentasi.
#
# Namun demikian, tingginya alokasi dana dalam bentuk simpanan tradisional juga menandakan rendahnya eksposur terhadap instrumen investasi seperti saham, obligasi, dan reksa dana. Misalnya, investasi rata-rata dalam saham hanya sebesar €590 (0,6% dari kekayaan bersih), sementara investasi dalam reksa dana sebesar €2.720 (2,6%). Selain itu, melalui analisis ini juga mengungkap bahwa tingginya preferensi terhadap simpanan konvensional membawa dampak berupa rendahnya imbal hasil, terutama ketika suku bunga bank sentral mengalami penurunan. Imbal hasil deposito berjangka tahunan pada periode terbaru tercatat hanya sebesar 2,3% secara bruto, tidak cukup untuk mengimbangi inflasi. [https://en.wikipedia.org/wiki/Demographics_of_Portugal, https://www.aman-alliance.org/Home/ContentDetail/84837]
#
# Karena tidak ada data langsung mengenai jumlah individu yang melakukan deposito berjangka, kita hanya bisa memperkirakan secara kasar seperti berikut:
#
# - Total simpanan berjangka: €100,704 miliar
# - Rata-rata simpanan per orang: €22.300
# - Perkiraan jumlah deposan = Total term deposit / Rata-rata simpanan per orang = €100.704 miliar / €22.300 ≈ 4,52 juta orang
#
# Ini berarti sekitar 42 % dari penduduk Portugal yang menyimpan di term deposit. Hal ini mengindikasikan bahwa term deposit memiliki market yang begitu besar sehingga menjadikan bank memiliki potensi yang lebih besar untuk mendapatkan term deposit (deposito berjangka) yang dapat memberikan stabilitas dana, sumber pendanaan, dan dukungan terhadap kegiatan kredit.
#
# Dalam konteks ini, sebuah bank di Portugal menjalankan beberapa kampanye pemasaran melalui panggilan telepon (telemarketing) dengan tujuan utama untuk mempromosikan produk deposito berjangka (term deposit) kepada nasabah dan calon nasabah. Kampanye ini dilakukan dalam berbagai periode, dengan strategi pemasaran langsung yang sangat bergantung pada interaksi personal via telepon. Telemarketing dilakukan untuk menarik, melibatkan dan mempertahankan nasabah dengan mempromosikan produk bank (term deposit) serta membangun hubungan jangka panjang yang kuat sehingga mendukung dan menstabilkan keuangan bank. Pada dataset ini, Hasil dari kampanye ini berupa data personal, ekonomi serta deskripsi kampanye yang telah dilakukan terhadap nasabah. Ketika nasabah setuju untuk melakukan deposit, target variabel 'y' akan diberi tanda `yes`, sebaliknya `no`.
#
# ---
# #### **Masalah**
#
# Produk deposito berjangka (term deposit) merupakan salah satu sumber pendanaan utama bagi industri perbankan. Menurut data dari European Central Bank (ECB), deposito dengan jangka waktu tetap memberi bank fleksibilitas likuiditas lebih tinggi karena dananya tidak dapat ditarik sewaktu-waktu, menjadikannya lebih stabil dibandingkan tabungan biasa. Hal ini menjadikan peningkatan penjualan deposito sebagai prioritas strategis dalam pengelolaan dana bank (https://data.ecb.europa.eu).
#
# Dataset yang digunakan dalam proyek ini berasal dari kampanye pemasaran langsung sebuah bank di Portugal yang dilakukan melalui telemarketing antara Mei 2008 hingga November 2010, dan telah dianalisis dalam publikasi ilmiah oleh Moro et al. (2014). Dalam periode tersebut, terdapat 41.188 interaksi telepon yang direkam, namun hanya sekitar 3.924 pelanggan (8,8%) yang akhirnya membuka deposito berjangka (https://archive.ics.uci.edu/ml/datasets/Bank+Marketing; Moro et al., 2014).
#
# Sebagai ilustrasi berbasis data: jika bank menghubungi 1.000 calon pelanggan, maka rata-rata hanya sekitar 88 pelanggan yang berhasil dikonversi menjadi pembuka deposito.
# Berdasarkan laporan statistik dari Banco de Portugal, rata-rata saldo deposito berjangka individu (retail term deposit) selama periode 2008–2010 berada pada kisaran €4.500 hingga €6.000 per nasabah. Oleh karena itu, angka €5.000 digunakan dalam proyek ini sebagai estimasi konservatif dan berbasis data (https://www.bportugal.pt/en/page/statistics).
#
# Dengan demikian, peningkatan efektivitas kampanye sebesar hanya 2 poin persentase—misalnya dari 8,8% menjadi 10,8%—dapat menambah sekitar 20 nasabah baru dari setiap 1.000 kontak. Dengan nominal deposito rata-rata €5.000 per pelanggan, maka potensi tambahan dana terhimpun adalah €100.000, hanya dari satu batch kampanye.
#
# Masalah utama yang ingin diselesaikan adalah:
#
# Bagaimana bank dapat mengidentifikasi strategi kampanye yang paling berdampak terhadap keputusan nasabah untuk membuka deposito berjangka, sehingga pendekatan pemasaran menjadi lebih efisien dan menghasilkan peningkatan konversi yang signifikan secara finansial?
#
# ---
# #### **Tujuan**
#
# Proyek ini dibangun di atas dua landasan utama: analisis eksploratif untuk memahami pola dalam data, dan pengembangan model prediktif untuk pengambilan keputusan yang presisi.
#
# 1. **Analytical Objective: Business Insight Generation**
# <br><br>Tujuan pertama adalah mengeksplorasi dataset secara menyeluruh untuk menemukan:
#     - Faktor-faktor utama yang memengaruhi keberhasilan kampanye, seperti durasi kontak, waktu pelaksanaan, dan karakteristik nasabah.
#     - Pola-pola interaksi yang efektif maupun kontra-produktif (misal kampanye terlalu sering).
#     - Rekomendasi praktis bagi tim marketing untuk meningkatkan efisiensi kontak dan alokasi sumber daya secara tepat sasaran.
#
# 2. **Predictive Objective: Machine Learning Application**
# <br><br>Tujuan dari proyek ini adalah membangun model machine learning untuk membantu bank menentukan apakah seorang pelanggan akan melakukan term deposit, berdasarkan informasi yang tersedia **hingga saat ini**.
#
#     Dataset yang digunakan merepresentasikan hasil dari interaksi telemarketing terakhir terhadap masing-masing pelanggan. Masing-masing baris dianggap mewakili **satu pelanggan unik**, tanpa riwayat kontak terpisah per individu.
#
#     **Model tidak terbatas hanya untuk prediksi kontak pertama**
#
#     Meskipun fitur seperti `campaign` menunjukkan jumlah total kontak yang sudah dilakukan terhadap seorang pelanggan, informasi ini justru merefleksikan **kondisi nyata saat ini** misalnya, "ini adalah kontak ke-2 atau ke-4 untuk pelanggan A." Karena itu:
#
#     - Model **tidak hanya memprediksi pada kontak pertama**
#     - Tapi juga memprediksi hasil kontak **saat ini**, terlepas dari sudah ke berapa kali pelanggan dihubungi
#
#     **Justifikasi Pendekatan Ini:**
#
#     - **Tidak ada ID pelanggan** → kita tidak bisa membedakan riwayat per orang
#     - **Tidak ada baris eksplisit untuk tiap urutan kontak** → dataset hanya menyimpan snapshot terakhir per pelanggan
#     - Maka, **satu baris = satu pelanggan** adalah asumsi paling aman dan praktis
#     - Fitur `campaign`, `previous`, dan `poutcome` tetap bisa digunakan karena nilainya sudah tersedia **sebelum prediksi dilakukan**
#
#     **Tujuan kedua adalah membangun model prediktif berbasis machine learning yang mampu:**
#
#     > Memprediksi apakah pelanggan akan melakukan term deposit pada saat mereka dihubungi, dengan mempertimbangkan informasi historis dan status saat ini tanpa menggunakan data masa depan seperti `duration`.
#
#     Model ini akan digunakan untuk:
#     - Membantu tim marketing memprioritaskan pelanggan yang paling potensial
#     - Mengurangi biaya kampanye dengan menyaring pelanggan yang kemungkinan besar tidak tertarik
#
# Dengan pendekatan ini, bank diharapkan tidak hanya mendapatkan insight retrospektif, tetapi juga kemampuan untuk mengoptimalkan keputusan kampanye secara proaktif ke depannya.
#
# ---
# #### **Pendekatan Analisis**
#
# Kami akan menganalisis karakteristik nasabah terlebih dahulu melalui data yang ada untuk mengetahui nasabah mana yang berminat untuk melakukan term deposit serta menganalisis faktor-faktor apa saja yang mempengaruhi keputusan nasabah untuk melakukan term deposit. Setelah itu, kami akan membuat model prediksi berdasarkan fitur yang ada untuk mengetahui probabilitas nasabah melakukan term deposit.
#
# ---
# #### **Pendekatan Metriks**
#
# Apabila dilihat dari dataset yang ada terdapat variabel y (target) yang menunjukan sebagai berikut:
#
# Target:
#
# `0 : Nasabah tidak melakukan term deposit`
#
# `1 : Nasabah melakukan term deposit`
#
# `Type 0 Error: Nasabah yang diprediksi tidak melakukan term deposit tetapi pada faktanya nasabah ini melakukan term deposit (False Negative)` -> Konsekuensi: kehilangan nasabah potensial
#
# `Type 1 Error: Nasabah yang diprediksi melakukan term deposit tetapi pada faktanya nasabah ini tidak melakukan term deposit (False Positive)` -> Konsekuensi: Pengeluaran biaya yang tidak tepat sasaran
#
# **Business Metric:**
#
# - Berdasarkan [LiveAgent](https://www.liveagent.com/customer-support-glossary/cost-per-call/), biaya panggilan telepon di portugal adalah 2.34 Euro - 4.85 Euro. Kita asumsikan bahwa cost dari tiap panggilan adalah 3.6 Euro.
# - Berdasarkan data dari [Institut Statistik Portugal](https://www.ine.pt/xportal/xmain?PUBLICACOESmodo=2&PUBLICACOESpub_boui=141619793&xpgid=ine_publicacoes&xpid=INE), pada tahun 2010 pendapatan rata rata penduduk per tahunnya adalah 23,811 Euro dengan pengeluaran untuk biaya hidup sebesar 20,391 Euro yang menyisakan disposable income sebesar 3,420 Euro.
# - Berdasarkan [Banco De Portugal](https://www.bportugal.pt/sites/default/files/anexos/papers/ab201014_e.pdf), rata rata orang akan menginvestasikan sekitar `2,695 Euro`.
# - Berdasarkan [Banco De Portugal](https://www.bportugal.pt/sites/default/files/anexos/pdf-boletim/ref_november10_e.pdf), Bunga pinjaman berada di kisaran 4.2 – 5.1% tergantung dari jangka waktu dan menurut [TradingEconomics](https://tradingeconomics.com/portugal/bank-lending-rate#:~:text=Bank%20Lending%20Rate%20in%20Portugal,source%3A%20European%20Central%20Bank) rata rata lending interest rate di portugal dari tahun 2003-2025 adalah 4.98%.
# - Berdasarkan [TheBanks](https://thebanks.eu/compare-banking-products/time-deposit-accounts/Portugal), deposit interest rate portugal berkisar antara 0.10% - 3% tergantung dari jangka waktunya. Apabila dilihat dari minimal depositonya, kita dapat menyimpulkan bahwa term deposit yang sesuai dengan kriteria yang ada adalah 0.10%
#
# Maka dari itu, dapat disimpulkan bahwa:
#
# Rata-rata investasi:
# - `2695 Euro`
#
# Keuntungan per nasabah (Kelas 1):
# - `Nominal deposit * (Bunga Pinjaman - Bunga deposit)` -> `2695 * (4.98%-0.10%) = 131 Euro per tahun`
#
# Potensi Keuntungan(berdasarkan jumlah nasabah yang ada pada dataset):
# - `131 Euro * 41188 = 5,395,628 Euro` -> apabila semua nasabah melakukan term deposit
#
# Kerugian:
# - Type 0 Error -> Apabila kehilangan nasabah yang akan mendepositkan uang sejumlah `2695 Euro`, maka bank akan mendapat kerugian sebesar `131 Euro` dari tiap nasabah yang hilang.
# - Type 1 Error -> Apabila bank mengeluarkan biaya untuk nasabah yang tidak melakukan term deposit, maka bank akan mengeluarkan biaya untuk setiap panggilannya. Kita asumsikan jumlah panggilan rata rata per nasabah adalah 5x panggilan berdasarkan data, maka untuk setiap panggilan yang tidak terkonversi, bank akan merugi sekitar `18 Euro`
# ---standar Afrika/OpenData dan laporan bunga deposito Portugal (2‑3% gross, pajak ~28%) kasi link

# %% [markdown]
# ## **Data Understanding**
#
# ### Attribute Information
#
# | Attribute | Data Type | Description |
# | --- | --- | --- |
# | age | Integer | Usia calon nasabah |
# | job | String | Pekerjaan calon nasabah |
# | marital | String | Status pernikahan calon nasabah |
# | education | String | Status pendidikan calon nasabah |
# | default | String | Pernahkah calon nasabah gagal bayar sebelumnya? |
# | housing | String | Apakah calon nasabah memiliki cicilan rumah? |
# | loan | String | Apakah calon nasabah memiliki pinjaman? |
# | contact | String | Jenis komunikasi yang digunakan |
# | month | String | Bulan dimana terakhir kali melakukan panggilan dengan nasabah pada tahun ini  |
# | day_of_week | String | Hari dimana terakhir kali melakukan panggilan dengan nasabah |
# | duration | Integer | durasi panggilan kampanye dalam detik |
# | campaign | Integer | Jumlah panggilan yang dilakukan selama kampanye untuk nasabah ini |
# | pdays | Integer | jumlah hari yang berlalu setelah nasabah terakhir dihubungi dari kampanye sebelumnya. |
# | previous | Integer | Jumlah panggilan yang dilakukan sebelum kampanye ini|
# | poutcome | String | Hasil dari kampanye sebelumnya |
# | emp.var.rate | Float | Employment Variation Rate :  perubahan jumlah orang yang bekerja dalam suatu periode waktu (dalam %) karena perubahan kondisi ekonomi pada negara Portugal |
# | cons.price.idx | Float | Consumer Price Index : Indikator untuk menilai perubahan rata-rata harga suatu barang dan jasa (indikator inflasi) pada negara Portugal  |
# | cons.conf.idx | Float | Consumer Confidence Index : Indikator untuk menilai kinerja perekonomian melalui tingkat konsumsi masyarakat pada negara Portugal  |
# | euribor3m | Float | Euribor 3 Month Rate : Tingkat suku bunga antar bank 3 bulan terakhir pada wilayah Eropa (indikator harian) |
# | nr.employed | Float | Indikator tenaga kerja Global pada negara Portugal  |
# | y | String | Apakah calon nasabah memutuskan untuk berlangganan deposito atau tidak |
#
# Catatan:
# - Detail fitur `education` :
#     - illiterate = buta huruf
#     - basic.4y = pendidikan formal hingga usia 9 tahun
#     - basic.6y = pendidikan formal hingga usia 11 tahun
#     - basic.9y = pendidikan formal hingga usia 14 tahun
#     - highschool = pendidikan formal hingga usia 17 tahun (Sekolah menegah atas)
#     - professional.course = kelas pelatihan kejuruan
#     - university.degree = pendidikan tingkat universitas
# - untuk `pdays`, angka 999 berarti nasabah tidak pernah dihubungi sebelumnya

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('bank-additional-full.csv', sep= ';')

# %%
df_ml = df.copy()

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %% [markdown]
# Insights:
# - Terdapat `41188 baris data dan 21 kolom` dengan proporsi `10 kolom numerikal dan 11 kolom kategorikal` yang menunjukan karakteristik nasabah dalam setiap barisnya
# - Apabila dilihat dari hasil diatas, tidak terdapat missing value tetapi ditemukan bahwa missing value pada dataset ditandai dengan nilai `unknown`

# %%
display(df.describe(),df.describe(include=['object']))
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %% [markdown]
# Insights:
#
# - Jumlah calon nasabah ada 41188
# - calon nasabah minimal berumur 17 tahun
# - rata rata umur calon nasabah yang dipanggil adalah 40 tahun
# - umur calon nasabah paling tua adalah 98 tahun
# - durasi panggilan terlama adalah 4918 detik (81 menit)
# - durasi rata rata tiap panggilan adalah 258 detik(4.3 menit)
# - Calon nasabah menerima setidaknya 1 panggilan dari kampanye ini
# - rata rata calon nasabah menerima 2-3 panggilan dari kampanye ini
# - Jumlah panggilan terbanyak adalah 56 panggilan untuk satu calon nasabah pada kampanye ini
# - Rata-rata calon nasabah belum pernah mengikuti campaign(belum pernah ditelpon sebelumnya)
# - Calon nasabah yang paling banyak ditawari term deposit adalah calon nasabah yang bekerja sebagai admin
# - Calon nasabah yang paling banyak ditawari term deposit adalah calon nasabah yang sudah menikah
# - Calon nasabah yang paling banyak ditawari term deposit adalah calon nasabah yang status pendidikan university.degree
# - Calon nasabah yang paling banyak ditawari term deposit adalah calon nasabah yang tidak pernah gagal bayar
# - Calon nasabah yang paling banyak ditawari term deposit adalah calon nasabah yang memiliki cicilan rumah
# - Calon nasabah yang paling banyak ditawari term deposit adalah calon nasabah yang memiliki pinjaman ke bank
# - Calon nasabah yang paling banyak ditawari term deposit adalah calon nasabah belum pernah melakukan term deposit
# - Calon nasabah paling banyak ditawari melalui telepon seluler
# - Kampanye terakhir paling banyak di bulan mei
# - kampanye terakhir paling banyak di hari kamis
# - kampanye yang telah dilakukan sebagian besar gagal

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ## **Checking Missing Values, Unique values & Duplicates**

# %% [markdown]
# ### Checking Unique Values

# %%
uniques = []
for col in df:
    uniques.append([col, df[col].nunique(), df[col].unique()])
unique_values = pd.DataFrame(columns=['Column Name', 'Number of Unique', 'Unique Sample'],
                     data=uniques)
pd.set_option('max_colwidth', None)
unique_values
# Out:
#        Column Name  Number of Unique  \
# 0              age                78
# 1              job                12
# 2          marital                 4
# 3        education                 8
# 4          default                 3
# 5          housing                 3
# 6             loan                 3
# 7          contact                 2
# 8            month                10
# 9      day_of_week                 5
# 10        duration              1544
# 11        campaign                42
# 12           pdays                27
# 13        previous                 8
# 14        poutcome                 3
# 15    emp.var.rate                10
# 16  cons.price.idx                26
# 17   cons.conf.idx                26
# 18       euribor3m               316
# 19     nr.employed                11
# 20               y                 2
#
# ...

# %% [markdown]
# Insights:
#
# - consumer.price.idx dan consumer.confidence.idx adalah indikator bulanan yang memiliki 26 unique value. hal ini berarti kedua variabel ini di update setiap bulannya sebanyak 2 sampai 3 kali
# - emp.var.rate dan nr.employed di update setiap 3 bulan
# - Nilai unknown terdapat pada kolom job, marital, education, default, housing dan loan
# - Kampanye dilakukan dari hari senin - jumat
# - Hanya terdapat data kampanye dari bulan maret - desember

# %% [markdown]
# ### Checking Missing Values

# %% [markdown]
# Karena missing values ditandai dengan nilai `unknown`, maka kita perlu cek kolom mana saja yang memiliki nilai `unknown`

# %%
columns_with_value = []
for col in df.columns:
    if 'unknown' in df[col].values:
        columns_with_value.append(col)
print(f"Columns containing the value 'unknown': {columns_with_value}")
# Out:
# Columns containing the value 'unknown': ['job', 'marital', 'education', 'default', 'housing', 'loan']

# %%
missing = []
for cols in columns_with_value:
    missing.append([cols, df[df[cols]=='unknown'].shape[0],(df[df[cols]=='unknown'].shape[0]/41188)*100])
missing_values = pd.DataFrame(columns=['Column Name', 'Number of missing', 'Percentage'],
                     data=missing)
missing_values
# Out:
#   Column Name  Number of missing  Percentage
# 0         job                330    0.801204
# 1     marital                 80    0.194231
# 2   education               1731    4.202680
# 3     default               8597   20.872584
# 4     housing                990    2.403613
# 5        loan                990    2.403613

# %% [markdown]
# Dalam dataset kampanye pemasaran bank ini, tidak ditemukan missing value secara teknis dalam bentuk null atau NaN. Namun, terdapat sejumlah variabel kategorikal seperti **job, marital, education, default, housing, dan loan** yang mengandung nilai "unknown", yang pada dasarnya berfungsi sebagai placeholder untuk data yang tidak diketahui atau tidak diberikan oleh nasabah.
#
# **Treatments for Analysis:**
#
# Selama proses analisis eksploratif, nilai "unknown" tidak dihapus atau diasumsikan hilang, melainkan diperlakukan sebagai kategori valid yang mencerminkan ketidaktahuan nasabah atau kegagalan sistem dalam mencatat informasi.
#
# Alasan utamanya:
# - Nilai "unknown" bisa menjadi sinyal perilaku yang penting: nasabah yang tidak ingin menjawab status pinjaman bisa jadi memiliki kecenderungan berbeda terhadap keputusan finansial.
# - Menghapus atau mengisi "unknown" pada tahap eksplorasi berpotensi menghilangkan informasi kontekstual yang relevan secara bisnis.

# %% [markdown]
# ### Checking Duplicates

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df[df.duplicated()] #pakai keep_last
# Out:
#        age          job   marital            education  default housing loan  \
# 1266    39  blue-collar   married             basic.6y       no      no   no
# 12261   36      retired   married              unknown       no      no   no
# 14234   27   technician    single  professional.course       no      no   no
# 16956   47   technician  divorced          high.school       no     yes   no
# 18465   32   technician    single  professional.course       no     yes   no
# 20216   55     services   married          high.school  unknown      no   no
# 20534   41   technician   married  professional.course       no     yes   no
# 25217   39       admin.   married    university.degree       no      no   no
# 28477   24     services    single          high.school       no     yes   no
# 32516   35       admin.   married    university.degree       no     yes   no
# 36951   45       admin.   married    university.degree       no      no   no
# ...

# %% [markdown]
# ## **Numerical Feature Data Distribution**

# %%
# from readline import insert_text

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe().columns
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
# Kolom numerik yang ingin divisualisasikan
num_cols = ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
       'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

plt.figure(figsize=(10,20), facecolor='white')
sns.set(style='whitegrid', palette='Set1')
plotnumber = 1

for features in num_cols:
    ax=plt.subplot(5,2, plotnumber)
    sns.histplot(x=features, data=df)
    plt.title(features)
    plt.tight_layout()
    plotnumber+=1

# %%
# Cek distribusi menggunakan Shapiro Wilk Test
from scipy.stats import shapiro

for cols in num_cols:
    stat, p = shapiro(df[cols])
    print('Kolom:', cols)
    print('Statistik:', stat)
    print('p-value:', p)
    
    if p > 0.05:
        print("Data terdistribusi normal (gagal tolak H0)")
    else:
        print("Data tidak terdistribusi normal (tolak H0)")
    print('\n')
# Out:
# Kolom: age
# Statistik: 0.9572414615024899
# p-value: 5.4319443630172027e-73
# Data tidak terdistribusi normal (tolak H0)
#
#
# Kolom: duration
# Statistik: 0.7216534008376556
# p-value: 1.801950785158919e-119
# Data tidak terdistribusi normal (tolak H0)
#
#
# Kolom: campaign
# Statistik: 0.5578417257109611
# p-value: 9.62073716982409e-133
# Data tidak terdistribusi normal (tolak H0)
#
#
# Kolom: pdays
# Statistik: 0.18297077044099874
# p-value: 1.9022011067120347e-151
# Data tidak terdistribusi normal (tolak H0)
#
#
# Kolom: previous
# Statistik: 0.3912366625006397
# p-value: 2.502841443983614e-142
# Data tidak terdistribusi normal (tolak H0)
#
#
# Kolom: emp.var.rate
# Statistik: 0.7620845388494727
# p-value: 3.9431429658268834e-115
# Data tidak terdistribusi normal (tolak H0)
#
#
# Kolom: cons.price.idx
# Statistik: 0.9339681073879422
# p-value: 9.712493978834933e-83
# Data tidak terdistribusi normal (tolak H0)
#
#
# Kolom: cons.conf.idx
# Statistik: 0.9239589892069009
# ...

# %%
ages = []
for i in range(len(df['age'].unique())):
    ages.append([df['age'].unique()[i], df[df['age']==df['age'].unique()[i]].shape[0], (df[df['age']==df['age'].unique()[i]].shape[0]/41188)*100])
age = pd.DataFrame(columns=['Age', 'Number of occurences', 'percentage'],
                     data=ages)
pd.set_option('max_colwidth', None)
age[:10].sort_values('percentage', ascending=False)
# Out:
#    Age  Number of occurences  percentage
# 2   37                  1475    3.581140
# 9   29                  1453    3.527727
# 6   41                  1278    3.102845
# 3   40                  1161    2.818782
# 4   45                  1103    2.677964
# 0   56                   704    1.709236
# 1   57                   646    1.568418
# 8   25                   598    1.451879
# 5   59                   463    1.124114
# 7   24                   463    1.124114

# %% [markdown]
# Insights:
# - Tidak ada data yang terdsitribusi normal
# - mayoritas nasabah yang dihubungi berkisar antara 30-60 tahun
# - durasi panggilan mayoritas berada dibawah 10 menit
# - mayoritas calon nasabah belum pernah mengikuti kampanye sebelumnya
# - mayoritas panggilan dilakukan saat nr.employed berada diatas 5100
# - mayoritas panggilan dilakukan saat euribor3m berada diangka 5

# %% [markdown]
# ## **Numerical Feature Correlation**

# %%
import numpy as np
# Pilih fitur numerik dan ubah target menjadi numerik
numerical_df = df.select_dtypes(include=['int64', 'float64'])
numerical_df['y'] = df['y'].map({'no': 0, 'yes': 1})

# Hitung korelasi
corr = numerical_df.corr()

# Buat mask untuk segitiga atas
mask = np.triu(np.ones_like(corr, dtype=bool))

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, mask=mask, cmap='coolwarm', annot=True, fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix (Lower Triangle Only)', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Insights:
# - Korelasi kuat antar indikator ekonomi(euribor3m, emp.var.rate, dan nr.employed). Hal ini menunjukkan bahwa indikator ekonomi tersebut sangat terhubung dan cenderung bergerak bersama.
# - Korelasi terhadap y:
#     - Korelasi positif yang cukup signifikan dengan `duration`, hal ini menandakan bahwa jika durasi kampanye dalam suatu panggilan besar maka kemungkinan calon nasabah melakukan term deposit akan lebih besar juga.
#     - Korelasi negatif yang sedang dengan `pdays`, hal ini menunjukan bahwa semakin lama waktu sejak nasabah dihubungi terakhir kali, semakin kecil kemungkinan mereka akan melakukan term deposit.
#     - `nr.employed` dan `euribor3m`: Korelasi negatif sedang terhadap y (−0.35 dan −0.31). Hal ini bisa menunjukkan bahwa saat kondisi ekonomi "baik" (banyak orang bekerja, suku bunga tinggi), konversi justru lebih rendah. Mungkin karena orang tidak butuh investasi tambahan saat ekonomi sedang stabil.

# %% [markdown]
# ## **Categorical Feature Distribution**

# %%
kategori = df.describe(include='object').columns.values

# Ukuran plot
plt.figure(figsize=(20, 20))
sns.set(style="whitegrid")

# Buat bar chart untuk masing-masing kategori
for i, kolom in enumerate(kategori, 1):
    plt.subplot(4, 3, i)
    proporsi = df[kolom].value_counts().sort_values(ascending=False)
    sns.barplot(x=proporsi.values, y=proporsi.index, palette='Set2')
    plt.title(f'Proporsi Kategori: {kolom}')
    plt.xlabel('Proporsi')
    plt.ylabel(kolom)

plt.tight_layout()
plt.show()

# %% [markdown]
# Insights:
# - Calon nasabah yang di-approach mayoritas adalah calon nasabah yang memiliki pekerjaan tetap, Hal ini terjadi karena calon nasabah yang memiliki pekerjaan tetap cenderung lebih stabil secara finansial dan memiliki resiko yang kecil(Nasabah dengan pekerjaan tetap lebih jarang gagal bayar cicilan atau tarik simpanan sebelum waktunya)
# - Calon nasabah yang di approach mayoritas adalah calon nasabah yang sudah menikah
# - Calon nasabah yang di approach paling banyak adalah calon nasabah yang memiliki jenjang pendidikan university.degree
# - kontak mayoritas dilakukan melalui telepon seluler
# - Mayoritas nasabah yang ditawari adalah calon nasabah yang belum pernah melakukan term deposit sebelumnya

# %% [markdown]
# ## **Target Feature Proportion**

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(20, 30))

# 1. Proporsi Berlangganan Deposito
plt.subplot(5, 2, 1)
sns.countplot(data=df, x='y', palette='Set2')
plt.title('Proporsi Klien Berlangganan Deposito')
plt.xlabel('Berlangganan Deposito')
plt.ylabel('Jumlah')

# 2. Distribusi Pekerjaan dan Keberhasilan Kampanye
plt.subplot(5, 2, 2)
sns.countplot(data=df, x='job', hue='y', palette='Set2')
plt.title('Distribusi Pekerjaan dan Keberhasilan Kampanye')
plt.xlabel('Jenis Pekerjaan')
plt.ylabel('Jumlah Nasabah')
plt.xticks(rotation=45)

# 3. Kontak per Bulan
plt.subplot(5, 2, 3)
sns.countplot(data=df, x='month', hue='y', order=['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec'], palette='coolwarm')
plt.title('Jumlah Kontak per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Kontak')

# 4. Hubungan euribor3m dan y
plt.subplot(5, 2, 4)
sns.boxplot(data=df, x='y', y='euribor3m', palette='Set2')
plt.title('euribor3m terhadap Keberhasilan Kampanye')
plt.xlabel('Berlangganan Deposito')
plt.ylabel('Euribor 3 Bulan')

# 5. Hubungan euribor3m dan y
plt.subplot(5, 2, 5)
sns.boxplot(data=df, x='y', y='cons.conf.idx', palette='Set2')
plt.title('cons.conf.idx terhadap Keberhasilan Kampanye')
plt.xlabel('Berlangganan Deposito')
plt.ylabel('Confidence Index')

# 6. Hubungan age dan y
plt.subplot(5, 2, 6)
sns.histplot(data = df, hue = 'y', x = df['age'], stat = 'count')
plt.title('Age terhadap Keberhasilan Kampanye')
plt.xlabel('Umur')
plt.ylabel('Count')

# 7. Distribusi Status Pernikahan dan Keberhasilan Kampanye
plt.subplot(5, 2, 7)
sns.countplot(data=df, x='marital', hue='y', palette='Set2')
plt.title('Distribusi Status Pernikahan dan Keberhasilan Kampanye')
plt.xlabel('Status Pernikahan')
plt.ylabel('Jumlah Nasabah')
plt.xticks(rotation=45)

# 8. hubungan poutcome dengan y
plt.subplot(5, 2, 8)
sns.countplot(data=df, x='poutcome', hue='y', palette='Set2')
plt.title('poutcome terhadap Keberhasilan Kampanye')
plt.xlabel('Berlangganan Deposito')
plt.xticks(rotation=45)
plt.ylabel('poutcome')

plt.subplot(5, 2, 9)
sns.histplot(data = df, hue = 'y', x = df['duration'], stat = 'count',kde = True)
plt.title('Durasi terhadap Keberhasilan Kampanye')
plt.xlabel('Durasi (detik)')
plt.xticks(rotation=45)
plt.ylabel('Count')

plt.subplot(5, 2, 10)
sns.histplot(data = df, hue = 'y', x = df['campaign'], stat = 'count',kde = True)
plt.title('jumlah kampanye terhadap Keberhasilan Kampanye')
plt.xlabel('Jumlah Kontak')
plt.xticks(rotation=45)
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# Cek batas atas dan bawah dari duration
IQR = df['duration'].quantile(0.75) - df['duration'].quantile(0.25)
lower_fence = df['duration'].quantile(0.25) - 1.5*IQR
upper_fence = df['duration'].quantile(0.75) + 1.5*IQR

upper_fence
# Out:
# 644.5

# %%
df[df['y']=="yes"]['euribor3m'].median()
# Out:
# 1.266

# %%
# Cek batas atas dan bawah dari campaign
campaign_IQR = df['campaign'].quantile(0.75) - df['campaign'].quantile(0.25)
campaign_lower_fence = df['campaign'].quantile(0.25) - 1.5*IQR
campaign_upper_fence = df['campaign'].quantile(0.75) + 1.5*IQR

campaign_upper_fence
# Out:
# 328.5

# %% [markdown]
# Insights:
# - Dari kampanye ini, terdapat 36548 (88.7%) calon nasabah yang tidak melakukan term deposit dan 4640 (11.26%) calon nasabah yang melakukan deposit
# - Calon nasabah dengan pekerjaan admin menjadi pekerjaan paling banyak yang melakukan term deposit diikuit oleh blue-collar dan technician. hal ini menunjukan bahwa calon nasabah yang paling mungkin melakukan term deposit adalah calon nasabah yang memiliki pekerjaan (memiliki produktifitas).
# - Bulan mei menjadi bulan dengan kegiatan kampanye terbanyak.
# - Status pernikahan memiliki pengaruh terhadap target value
# - Calon nasabah melakukan term deposit ketika nilai euribor3m sedang relatif tinggi, hal ini berkaitan dengan tingginya hasil dari deposito yang disebabkan sulitnya bank untuk melakukan pinjaman antar bank sehingga bank sangat bergantung pada term deposit dengan memberikan penawaran yang sangat menarik.
# - Calon nasabah yang memiliki status pernikahan 'married' memiliki jumlah 'yes' paling banyak
# - kampanye yang dilakukan terhadap calon nasabah yang memiliki poutcome = 'nonexistent' memiliki hasil yang lebih baik dibandingkan dengan calon nasabah yang lainnya
# - durasi kontak dibawah 644 detik memiliki outcome yang lebih baik
# - calon nasabah dengan kontak dibawah 6 kali memiliki kecenderungan lebih besar untuk melakukan term deposit

# %%
df['duration'].median()
# Out:
# 180.0

# %%
# Kelompokkan durasi ke dalam rentang
bins = [17, 25, 35, 45, 55, 65, 100]
labels = ['17-24', '25-34', '35-44', '45-54', '55-64', '65+']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# %% [markdown]
# ## **Conversion Rate in Each Category**

# %% [markdown]
# ### What is Conversion Rate?
#
# Conversion rate adalah persentase pengunjung yang menyelesaikan tindakan yang diinginkan seperti membeli produk, mengisi formulir, dll. Secara sederhana, conversion rate adalah cara untuk mengetahui seberapa efektif upaya pemasaran Anda dalam mengubah pengunjung menjadi pelanggan atau mendorong mereka melakukan tindakan yang Anda inginkan. Conversion rate membantu perusahaan memahami seberapa efektif kampanye pemasaran yang dilakukan dalam mencapai tujuan yang diinginkan. Dengan mengetahui tingkat konversi, perusahaan dapat mengidentifikasi area yang perlu diperbaiki dan mengoptimalkan strategi pemasaran untuk mendapatkan hasil yang lebih baik.
#
# Rumus Conversion rate:
#
# *Conversion Rate = (Jumlah Konversi / Jumlah Total Pengunjung) * 100%*

# %% [markdown]
# Untuk memperjelas conversion rate berdasarkan umur nasabah, kami melakukan binning terhadap data umur yang akan mengelompokan nasabah berdasarkan 6 kategori yaitu:
# - 17-24 tahun
# - 25-34 tahun
# - 35-44 tahun
# - 45-54 tahun
# - 55-64 tahun
# - 65+ tahun

# %% [markdown]
# #### Feature Engineering

# %%
# Kelompokkan umur ke dalam rentang
bins = [17, 25, 35, 45, 55, 65, 100]
labels = ['17-24', '25-34', '35-44', '45-54', '55-64', '65+']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# %% [markdown]
# ### Age Range

# %% [markdown]
# Umur sering dikaitkan dengan conversion rate dalam marketing karena umur adalah salah satu indikator utama yang memengaruhi perilaku konsumen, preferensi, dan cara pengambilan keputusan. Umur berpengaruh besar terhadap pola pikir, kebutuhan, daya beli, dan perilaku digital konsumen. Maka, mengaitkan umur dengan conversion rate membantu marketer menyesuaikan strategi agar lebih tepat sasaran dan efektif.

# %%
# Hitung total dan yang y = yes
conversion_data = df.groupby('age_group')['y'].value_counts().unstack().fillna(0)
conversion_data['conversion_rate'] = conversion_data['yes'] / (conversion_data['yes'] + conversion_data['no'])
# Sort berdasarkan conversion rate
conversion_data_sorted = conversion_data.sort_values(by='conversion_rate', ascending=False)

# Visualisasi
plt.figure(figsize=(8, 6))
bars = sns.barplot(
    x=conversion_data_sorted.index,
    y=conversion_data_sorted['conversion_rate'],
    hue=conversion_data_sorted.index,
    order=conversion_data_sorted.index
)

# Tambahkan label persentase di atas setiap batang
for bar in bars.patches:
    height = bar.get_height()
    bars.annotate(f'{height:.1%}',
                  xy=(bar.get_x() + bar.get_width() / 2, height),
                  xytext=(0, 5),  # offset di atas bar
                  textcoords='offset points',
                  ha='center', va='bottom', fontsize=10)

# Format plot
plt.title('Conversion Rate berdasarkan Kelompok Usia (Diurutkan)')
plt.xlabel('Kelompok Usia')
plt.ylabel('Conversion Rate')
plt.ylim(0, 1)
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
conversion_data_sorted
# Out:
# y             no   yes  conversion_rate
# age_group
# 65+          350   313         0.472097
# 17-24        812   256         0.239700
# 55-64       3083   484         0.135688
# 25-34      12020  1666         0.121730
# 35-44      12332  1168         0.086519
# 45-54       7951   753         0.086512

# %% [markdown]
# Insights:
#
# - `Kelompok usia 65+ memiliki conversion rate tertinggi (47.2%)`. Hal ini terjadi karena mereka cenderung menghindari risiko dan lebih memilih produk keuangan yang aman seperti term deposit dibandingkan produk berisiko tinggi seperti saham atau reksa dana. Ini menunjukkan bahwa segmen lansia adalah target paling responsif dan potensial untuk produk term deposit. Namun, kelompok umur ini tidak bisa dijadikan segmen paling potensial secara bisnis karena banyak dari mereka sudah di masa pasca-produktif sehingga mereka cenderung menyimpan dana yang sudah ada, bukan menambahnya secara rutin.
# - `Kelompok usia 17–24 memiliki konversi cukup tinggi (23.97%)`.
# - `Kelompok usia produktif (25–44) mendominasi kampanye, tapi memberikan konversi rendah (12.2%)`. Karena kelompok ini berada di usia produktif, mereka memiliki kemungkinan untuk memiliki ketertarikan pada produk investasi dengan return lebih tinggi serta lebih kritis dan selektif terhadap produk keuangan yang menjadikan kedua hal ini indikasi bahwa perlu adanya evaluasi pendekatan terhadap kelompok usia produktif

# %% [markdown]
# ### Job

# %% [markdown]
# Conversion rate dalam telemarketing bank sangat dipengaruhi oleh jenis pekerjaan nasabah. Hal ini karena jenis pekerjaan mencerminkan kestabilan finansial, preferensi risiko, dan kebutuhan likuiditas, yang semuanya berpengaruh langsung terhadap minat dan kemampuan nasabah untuk membeli produk term deposit.
#
# Term deposit mengharuskan dana dikunci selama periode tertentu. Oleh karena itu, nasabah yang memiliki penghasilan tetap dan stabil (seperti pegawai swasta) lebih percaya diri untuk menyisihkan dana dalam jangka waktu tertentu tanpa mengganggu kebutuhan sehari-hari. Sebaliknya, pekerja lepas, freelancer, atau pengusaha yang menghadapi pendapatan fluktuatif akan lebih memilih produk keuangan yang likuid (seperti tabungan atau reksa dana pasar uang).

# %%
df[df['y']=='yes']['campaign']
# Out:
# 75       1
# 83       1
# 88       1
# 129      1
# 139      1
#         ..
# 41174    1
# 41178    2
# 41181    1
# 41183    1
# 41186    1
# Name: campaign, Length: 4640, dtype: int64

# %%
# Hitung jumlah total dan jumlah yang 'yes' untuk tiap pekerjaan
job_conversion = df.groupby('job')['y'].value_counts().unstack().fillna(0)
job_conversion['conversion_rate'] = job_conversion['yes'] / (job_conversion['yes'] + job_conversion['no'])

# Urutkan dari yang tertinggi
job_conversion_sorted = job_conversion.sort_values(by='conversion_rate', ascending=False)

# Visualisasi
plt.figure(figsize=(10, 6))
bars = sns.barplot(
    x=job_conversion_sorted.index,
    y=job_conversion_sorted['conversion_rate'],
    palette='flare'
)

# Tambahkan label persentase di atas batang
for bar in bars.patches:
    height = bar.get_height()
    bars.annotate(f'{height:.1%}',
                  xy=(bar.get_x() + bar.get_width() / 2, height),
                  xytext=(0, 5),
                  textcoords='offset points',
                  ha='center', va='bottom', fontsize=10)

# Format plot
plt.title('Conversion Rate berdasarkan Pekerjaan (job)')
plt.xlabel('Pekerjaan')
plt.ylabel('Conversion Rate')
plt.xticks(rotation=45)
plt.ylim(0, 1)
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
job_conversion_sorted
# Out:
# y                no   yes  conversion_rate
# job
# student         600   275         0.314286
# retired        1286   434         0.252326
# unemployed      870   144         0.142012
# admin.         9070  1352         0.129726
# management     2596   328         0.112175
# unknown         293    37         0.112121
# technician     6013   730         0.108260
# self-employed  1272   149         0.104856
# housemaid       954   106         0.100000
# entrepreneur   1332   124         0.085165
# services       3646   323         0.081381
# blue-collar    8616   638         0.068943

# %% [markdown]
# Insights:
# - Mahasiswa dan pensiunan memiliki conversion rate paling tinggi, hal ini terjadi karena beberapa hal ini:
#     - Mahasiswa belum memiliki pengeluaran tetap yang besar
#     - Mahasiswa memiliki kecenderungan untuk memikirkan/membangun masa depannya
#     - Mahasiswa dan Pensiunan memiliki sumber penghasilan yang terbatas sehingga melihat term deposit ini sebagai sarana investasi yang rendah resiko
#     - Mahasiswa dan Pensiunan cenderung lebih berhati-hati dalam mengalirkan uangnya dan cenderung memilih investasi yang memiliki resiko yang rendah
#
#     *Apabila dilihat dari jumlah nasabah yang dihubungi dengan nasabah yang melakukan term deposit, mahasiswa dan pensiunan memiliki jumlah yang jauh lebih kecil dibandingkan dengan pekerjaan lain seperti (admin, management, services, dll.) hal ini berkaitan dengan teori pendapatan dan konsumsi nya Keynes yang menjelaskan bahwa ketika pendapatan naik akan ada 2 hal yang ikut naik juga yaitu consumption dan saving, tetapi proporsi konsumsi dan saving itu sendiri akan sangat dipengaruhi oleh tingkat kenaikan pendapatan itu sendiri. ketika pendapatan seseorang masih relatif rendah, ia akan cenderung lebih banyak untuk meningkatkan konsumsinya,dimana hal ini sejalan dengan teori hierarki Maslowe. Orang-orang dengan kenaikan pendapatan rendah akan cenderung berusaha untuk memenuhi kebutuhannya(safety: terhindar dari rasa lapar, dll.), hal ini akhirnya menyebabkan mereka akan lebih berhati-hati ketika menyimpan uang/investasi. Maka dari itu orang-orang seperti mahasiswa dan pensiunan akan cenderung untuk memanfaatkan instrumen investasi yang memiliki resiko rendah.*
# - Calon nasabah yang belum memiliki pekerjaan memiliki conversion rate yang lebih tinggi dibanding dengan calon nasabah yang sudah memiliki pekerjaan, hal ini dapat terjadi karena calon nasabah ini sementara ini belum memiliki pekerjaan tetapi memiliki uang dan ingin mengamankan uang yang mereka miliki
# - Calon nasabah yang memiliki pekerjaan dilingkup yang lebih professional memiliki conversion rate yang lebih rendah dibanding mahasiswa, pensiunan dan pengangguran, hal ini dapat terjadi karena calon nasabah yang memiliki pekerjaan ini cenderung lebih kritis dengan penawaran bank dan mungkin juga sudah memiliki produk keuangan lainnya.

# %% [markdown]
# Notes:
#
# ***Kenapa student conversion ratenya paling tinggi?***
#
# *Berdasarkan teori Keynes, terkait dengan pendapatan dan konsumsi, ketika pendapatan naik akan ada 2 hal yang ikut naik juga yaitu consumption dan saving, tetapi proporsi konsumsi dan saving itu sendiri akan sangat dipengaruhi oleh tingkat kenaikan pendapatan itu sendiri. ketika pendapatan seseorang masih relatif rendah, ia akan cenderung lebih banyak untuk meningkatkan konsumsinya,dimana hal ini sejalan dengan teori hierarki Maslowe. Orang-orang dengan kenaikan pendapatan rendah akan cenderung berusaha untuk memenuhi kebutuhannya(safety: terhindar dari rasa lapar, dll.), hal ini akhirnya menyebabkan mereka akan lebih berhati-hati ketika menyimpan uang/investasi. Maka dari itu orang-orang seperti mahasiswa dan pensiunan akan cenderung untuk memanfaatkan instrumen investasi yang memiliki resiko rendah.*

# %% [markdown]
# ### Month

# %% [markdown]
# bulan memiliki keterkaitan dengan conversion rate karena dalam satu bulan terdapat beberapa kejadian/event yang mungkin membantu marketing dalam menyesuaikan penawaran dengan kejadian/event yang terjadi dalam bulan tertentu sehingga targetting calon nasabah menjadi lebih terarah dan tepat sasaran.

# %%
# Hitung jumlah total dan jumlah yang 'yes' untuk tiap pekerjaan
month_conversion = df.groupby('month')['y'].value_counts().unstack().fillna(0)
month_conversion['conversion_rate'] = month_conversion['yes'] / (month_conversion['yes'] + month_conversion['no'])

# Urutkan dari yang tertinggi
month_conversion_sorted = month_conversion.sort_values(by='conversion_rate', ascending=False)

# Visualisasi
plt.figure(figsize=(10, 6))
bars = sns.barplot(
    x=month_conversion_sorted.index,
    y=month_conversion_sorted['conversion_rate'],
    palette='flare'
)

# Tambahkan label persentase di atas batang
for bar in bars.patches:
    height = bar.get_height()
    bars.annotate(f'{height:.1%}',
                  xy=(bar.get_x() + bar.get_width() / 2, height),
                  xytext=(0, 5),
                  textcoords='offset points',
                  ha='center', va='bottom', fontsize=10)

# Format plot
plt.title('Conversion Rate berdasarkan bulan')
plt.xlabel('bulan')
plt.ylabel('Conversion Rate')
plt.xticks(rotation=45)
plt.ylim(0, 1)
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
month_conversion_sorted
# Out:
# y         no  yes  conversion_rate
# month
# mar      270  276         0.505495
# dec       93   89         0.489011
# sep      314  256         0.449123
# oct      403  315         0.438719
# apr     2093  539         0.204787
# aug     5523  655         0.106021
# jun     4759  559         0.105115
# nov     3685  416         0.101439
# jul     6525  649         0.090466
# may    12883  886         0.064347

# %% [markdown]
# Insights:
# - Pekerjaan dengan Conversion Rate Tertinggi:
#
#     - Maret (mar): 50.5%
#     - Desember (dec): 48.9%
#     - September (sep): 44.9%
#     - Oktober (oct): 43.9%
#
# Kampanye yang dilakukan pada bulan-bulan ini menunjukkan efektivitas tinggi, kemungkinan karena momen waktu yang lebih kondusif, sedikitnya gangguan eksternal, atau kesesuaian timing dengan kebutuhan nasabah.
#
# - Pekerjaan dengan Conversion Rate Rendah:
#
#     - Mei (may): 6.4%
#
#     - Juli (jul): 9.0%
#
#     - November (nov): 10.1%
#
#     - Juni (jun): 10.5%
#
# Ini bisa menandakan bahwa kampanye di bulan-bulan tersebut kurang efektif, bisa karena musim liburan, terlalu banyak kampanye sebelumnya, atau kelelahan dari pelanggan (campaign fatigue).
#
# Kesimpulan:
#
# Conversion rate sangat bervariasi antar bulan, dari hanya 6.4% di Mei hingga 50.5% di Maret. Ada kemungkinan bahwa faktor musiman atau waktu dalam tahun memiliki pengaruh besar terhadap keberhasilan kampanye.
#
# Menjalankan kampanye di bulan dengan conversion rate historis tinggi (Maret, Desember, September, Oktober) bisa meningkatkan ROI (Return on Investment) secara signifikan.

# %% [markdown]
# ### Previous Campaign

# %%
# Hitung jumlah total dan jumlah yang 'yes' untuk tiap pekerjaan
previous_conversion = df.groupby('previous')['y'].value_counts().unstack().fillna(0)
previous_conversion['conversion_rate'] = previous_conversion['yes'] / (previous_conversion['yes'] + previous_conversion['no'])

# Urutkan dari yang tertinggi
previous_conversion_sorted = previous_conversion.sort_values(by='conversion_rate', ascending=False)

# Visualisasi
plt.figure(figsize=(10, 6))
bars = sns.barplot(
    x=previous_conversion_sorted.index,
    y=previous_conversion_sorted['conversion_rate'],
    palette='flare'
)

# Tambahkan label persentase di atas batang
for bar in bars.patches:
    height = bar.get_height()
    bars.annotate(f'{height:.1%}',
                  xy=(bar.get_x() + bar.get_width() / 2, height),
                  xytext=(0, 5),
                  textcoords='offset points',
                  ha='center', va='bottom', fontsize=10)

# Format plot
plt.title('Conversion Rate berdasarkan previous campaign')
plt.xlabel('Previous Campaign')
plt.ylabel('Conversion Rate')
plt.xticks(rotation=45)
plt.ylim(0, 1)
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
previous_conversion_sorted
# Out:
# y              no     yes  conversion_rate
# previous
# 5             5.0    13.0         0.722222
# 6             2.0     3.0         0.600000
# 3            88.0   128.0         0.592593
# 4            32.0    38.0         0.542857
# 2           404.0   350.0         0.464191
# 1          3594.0   967.0         0.212015
# 0         32422.0  3141.0         0.088322
# 7             1.0     0.0         0.000000

# %% [markdown]
# Insights:
#
# Grafik ini menunjukkan hubungan antara **jumlah kampanye sebelumnya yang telah menghubungi nasabah** (`previous`) dengan kemungkinan nasabah menerima penawaran pada kampanye saat ini (**conversion rate**).
#
# Temuan Utama:
# - **0 kontak sebelumnya** → *Hanya* **8.8%** conversion rate.
# - **1 kontak sebelumnya** → Naik menjadi **21.2%**.
# - **2 kontak sebelumnya** → Meningkat tajam ke **46.4%**
#
# Insight Penting:
# - Terdapat **korelasi positif** antara jumlah kampanye sebelumnya dengan peluang konversi, *hingga titik optimal* di **5 kontak**.
# - **First contact (0 kontak)** sangat tidak efektif.
# - Setelah 5 kontak, terjadi penurunan efektivitas yang bisa disebabkan oleh **campaign fatigue** atau karakteristik nasabah yang tidak tertarik.
#
# Berdasarkan visualisasi conversion rate terhadap jumlah kampanye sebelumnya (previous), dapat disimpulkan bahwa semakin sering nasabah dihubungi pada kampanye sebelumnya, semakin besar kemungkinan mereka untuk menerima penawaran pada kampanye saat ini. Nasabah yang belum pernah dihubungi sebelumnya memiliki conversion rate yang sangat rendah, yaitu hanya 8.8%. Namun, angka ini meningkat secara signifikan seiring bertambahnya jumlah kontak sebelumnya, hingga mencapai puncaknya pada 5 kali kontak dengan conversion rate sebesar 72.2%. Hal ini menunjukkan bahwa strategi retargeting sangat efektif, terutama ketika dilakukan secara bertahap dalam beberapa kampanye. Meski begitu, terdapat indikasi penurunan efektivitas setelah kontak kelima, seperti terlihat pada penurunan conversion rate menjadi 60.0% saat nasabah dihubungi 6 kali, dan bahkan 0.0% pada 7 kali (kemungkinan karena jumlah sampel yang sangat kecil atau outlier). Ini mengindikasikan adanya titik jenuh atau kelelahan pelanggan (campaign fatigue) setelah terlalu banyak dihubungi. Oleh karena itu, strategi kampanye yang optimal adalah dengan melakukan tindak lanjut secara terukur (maksimal 5 kali kontak) dan menghindari pengulangan yang berlebihan agar tidak menurunkan potensi konversi.

# %% [markdown]
# **Insight Conversion Rate Kampanye Term Deposit**
#
# Analisis terhadap tingkat konversi menunjukkan bahwa keberhasilan kampanye sangat bergantung pada karakteristik calon nasabah, waktu kampanye, serta jumlah kontak yang dilakukan. Beberapa kelompok menunjukkan respons yang tinggi, namun belum tentu memiliki nilai bisnis yang tinggi secara jangka panjang.
#
# - **Kelompok usia lanjut (65+) memiliki tingkat konversi tertinggi sebesar 47.2%**
#   Hal ini masuk akal karena mereka cenderung menghindari risiko dan lebih memilih instrumen investasi yang aman seperti term deposit. Meskipun responsif, kelompok ini tidak ideal untuk dijadikan target utama dari sisi bisnis karena mereka sudah berada dalam fase pasca-produktif dan lebih fokus mempertahankan aset daripada menumbuhkannya.
#
# - **Kelompok usia 17–24 juga menunjukkan tingkat konversi yang cukup tinggi (23.97%)**, sementara **usia produktif (25–44)** yang justru paling banyak ditargetkan hanya memberikan konversi rendah (12.2%).
#   Hal ini menandakan perlunya evaluasi pendekatan terhadap segmen usia produktif yang cenderung lebih kritis dan terbuka terhadap alternatif investasi berisiko lebih tinggi.
#
# - **Profesi mahasiswa dan pensiunan memiliki conversion rate tertinggi** dibanding profesi lain. Beberapa alasan utama:
#   - Mereka cenderung memiliki pengeluaran tetap yang rendah.
#   - Mereka lebih berhati-hati secara finansial.
#   - Mereka melihat term deposit sebagai sarana investasi aman dan terjangkau.
#
#   Meskipun jumlah mereka kecil secara absolut, perilaku mereka mencerminkan teori ekonomi seperti *teori konsumsi dan pendapatan Keynes* serta *hierarki kebutuhan Maslow*, di mana mereka yang berada pada tahap kebutuhan dasar lebih condong memilih instrumen keuangan yang stabil dan tidak berisiko.
#
# - **Calon nasabah yang belum memiliki pekerjaan** ternyata memiliki conversion rate lebih tinggi dibanding mereka yang sudah bekerja.
#   Hal ini mungkin karena mereka ingin mengamankan dana yang sudah dimiliki selama belum ada penghasilan tetap. Sebaliknya, **pekerja di sektor profesional** justru memiliki conversion rate yang lebih rendah karena kemungkinan sudah memiliki diversifikasi produk keuangan atau lebih kritis terhadap penawaran bank.
#
# **Waktu Kampanye**
#
# - Bulan-bulan dengan **conversion rate tertinggi**:
#   - Maret (**50.5%**)
#   - Desember (**48.9%**)
#   - September (**44.9%**)
#   - Oktober (**43.9%**)
#
#   Momentum kampanye di bulan-bulan ini tampaknya selaras dengan kebutuhan nasabah atau suasana yang lebih kondusif untuk mempertimbangkan penawaran baru.
#
# - Bulan-bulan dengan **conversion rate terendah**:
#   - Mei (**6.4%**)
#   - Juli (**9.0%**)
#   - November (**10.1%**)
#   - Juni (**10.5%**)
#
#   Hal ini dapat dikaitkan dengan kelelahan akibat terlalu banyak kampanye (*campaign fatigue*), musim liburan, atau waktu yang kurang tepat.
#
# **Jumlah Kontak Sebelumnya**
#
# - **0 kontak** → hanya **8.8%**
# - **1 kontak** → naik ke **21.2%**
# - **2 kontak** → melonjak ke **46.4%**
#
# > Terdapat **korelasi positif** antara jumlah kampanye sebelumnya dengan peluang konversi, *hingga titik optimal* di **5 kontak**.
# > Setelah itu, tingkat konversi justru menurun, kemungkinan besar akibat *campaign fatigue* atau resistensi dari nasabah yang memang tidak tertarik sejak awal.

# %% [markdown]
# ## **Analysis Summary**
#
# Berdasarkan analisis terhadap data nasabah dan performa kampanye term deposit, terdapat pola yang konsisten bahwa keberhasilan konversi sangat dipengaruhi oleh kombinasi faktor demografis, perilaku, waktu kampanye, serta indikator ekonomi.
#
# Meskipun kampanye sebagian besar menargetkan kelompok usia produktif dan pekerja tetap, justru konversi tertinggi ditemukan pada kelompok dengan karakteristik finansial yang lebih konservatif dan kebutuhan investasi yang aman, seperti mahasiswa, pensiunan, dan kelompok usia lanjut.
#
# Durasi panggilan yang lebih panjang, jumlah kontak yang cukup (namun tidak berlebihan), serta waktu kampanye yang tepat (bulan Maret, Desember, September, dan Oktober) juga berperan penting dalam meningkatkan efektivitas kampanye. Selain itu, indikator ekonomi seperti `euribor3m` dan `nr.employed` memiliki pengaruh signifikan, menunjukkan bahwa kondisi makro juga turut membentuk perilaku calon nasabah terhadap produk term deposit.
#
# ## Karakteristik Nasabah dengan Kecenderungan Tinggi Melakukan Term Deposit
#
# Berikut adalah karakteristik calon nasabah yang lebih mungkin untuk mengatakan "yes" terhadap penawaran term deposit:
#
# ### 1. Usia
# - Lansia (65+): sangat tinggi (47.2%)
# - Muda (17–24): cukup tinggi (23.97%)
# - Usia produktif (25–44): jumlah besar namun konversi rendah (12.2%)
#
# ### 2. Pekerjaan
# - Mahasiswa: konversi tinggi karena sifat konservatif dan terbatasnya pengeluaran
# - Pensiunan: konversi tinggi karena kecenderungan memilih investasi aman
# - Pengangguran/Belum bekerja: konversi cukup tinggi, kemungkinan ingin mengamankan aset
# - Admin dan blue-collar: jumlah absolut tinggi dalam kelompok yang berhasil melakukan term deposit, menunjukkan potensi jika pendekatannya tepat
#
# ### 3. Status Pernikahan
# - Menikah: mayoritas dalam kelompok yang berhasil konversi
# - Belum pernah mengikuti kampanye sebelumnya (`poutcome = nonexistent`)
#
# ### 4. Pendidikan
# - Berpendidikan tinggi (university degree): paling banyak dihubungi dan potensial jika pendekatannya tepat
#
# ### 5. Durasi dan Frekuensi Kontak
# - Durasi panggilan yang lebih panjang (namun < 644 detik) cenderung lebih efektif
# - Jumlah kontak sebelumnya 1–5 kali meningkatkan konversi
# - Efektivitas menurun setelah 5 kontak, diduga karena campaign fatigue
#
# ### 6. Waktu Kampanye
# - Bulan dengan tingkat konversi tinggi:
#   - Maret
#   - Desember
#   - September
#   - Oktober
#
# ### 7. Kondisi Ekonomi saat Kampanye
# - `euribor3m` tinggi: nasabah lebih tertarik karena imbal hasil deposito lebih menarik
# - `nr.employed` tinggi: konversi cenderung lebih rendah karena nasabah merasa kondisi finansial sudah cukup stabil
#
# ## Rekomendasi
# Dengan memahami karakteristik di atas, strategi kampanye dapat disesuaikan untuk:
# - Menargetkan segmen dengan potensi konversi tinggi
# - Menghindari over-contact yang menyebabkan campaign fatigue
# - Memilih waktu kampanye berdasarkan pola konversi historis
# - Mengoptimalkan pendekatan pada kelompok yang konservatif secara finansial

# %% [markdown]
# # **Preprocessing**
#
# #### Pemeriksaan Struktur Data (Machine Learning)
#
# Sebelum membangun pipeline machine learning, kita perlu memastikan beberapa aspek penting dari struktur dataset:
#
# - Apakah ada duplikasi data yang bisa menyebabkan bias?
# - Apakah format dan tipe data sudah sesuai (numerik vs kategorikal)?
# - Apakah jumlah kelas target `y` seimbang atau imbalanced?
# - Apakah terdapat fitur yang berpotensi menyebabkan data leakage?
#
# Langkah ini bersifat ringkas karena eksplorasi sebagian telah dilakukan sebelumnya (di bagian EDA), dan kita hanya akan fokus pada komponen yang relevan untuk preprocessing dan modeling.

# %% [markdown]
# ##### **Duplikasi Data**
#
# Pada tahap awal ini, kita mengecek duplikat berdasarkan keseluruhan baris (`df.duplicated()` tanpa `subset`) karena tidak terdapat kolom unik seperti ID pelanggan atau timestamp kontak. Dalam konteks kampanye telemarketing bank, dua baris yang benar-benar identik (termasuk informasi pelanggan dan hasil kontak) kemungkinan besar merupakan duplikasi data yang tidak dibutuhkan.
#
# > Jika di kemudian hari ditemukan adanya kolom identifikasi unik (misalnya: contact ID, waktu kontak), maka akan lebih tepat menggunakan `subset` untuk mengevaluasi duplikasi berdasarkan atribut-atribut relevan saja, seperti karakteristik pelanggan dan hasil kampanye.

# %%
print(f"Ukuran awal dataset: {df_ml.shape}")

# Cek duplikasi
duplicates = df_ml.duplicated().sum()
print(f"Jumlah duplikat: {duplicates}")
# Out:
# Ukuran awal dataset: (41188, 21)
# Jumlah duplikat: 12

# %% [markdown]
# Dalam konteks kampanye telemarketing, baris yang identik secara penuh (termasuk informasi pelanggan, kontak, dan hasilnya) tidak memberikan nilai tambah bagi model, bahkan bisa menyebabkan model terlalu yakin terhadap pola tertentu yang sebenarnya tidak mewakili populasi secara umum.
#
# Oleh karena itu, baris duplikat akan dihapus dari dataset.

# %%
# Hapus duplikat
df_ml.drop_duplicates(inplace=True)
print(f"Ukuran data setelah duplikat dihapus: {df_ml.shape}")
# Out:
# Ukuran data setelah duplikat dihapus: (41176, 21)

# %% [markdown]
# ##### **Deteksi Fitur yang Berpotensi Menyebabkan Leakage**
#
# Salah satu prinsip penting dalam pembangunan model machine learning yang valid adalah memastikan bahwa semua fitur input hanya menggunakan informasi yang **tersedia sebelum keputusan diambil**.
#
# Dalam konteks kampanye telemarketing ini, kita bertujuan memprediksi apakah pelanggan akan melakukan term deposit **pada saat kampanye berlangsung**, sebelum hasil kontak diketahui.
#
# Oleh karena itu, kita perlu mewaspadai fitur yang mungkin tampak valid, tetapi sebenarnya mengandung informasi **masa depan** yang baru tersedia setelah tindakan diambil.
#
# **Kasus Khusus: Kolom `duration`**
#
# Fitur `duration` menunjukkan **lama panggilan terakhir dalam detik**. Sekilas, ini tampak sebagai prediktor yang sangat kuat karena pelanggan yang berbicara lebih lama sering kali lebih tertarik.
#
# Namun, ini justru berbahaya karena:
# - Nilai `duration` **baru diketahui setelah panggilan dilakukan**
# - Artinya, saat kita ingin memutuskan *apakah pelanggan layak dihubungi*, informasi ini **belum tersedia**
# - Menyertakan `duration` dalam pelatihan model akan menyebabkan **temporal leakage**, di mana model belajar dari hasil keputusan yang seharusnya belum terjadi
#
# Maka, `duration` akan dihapus dari dataset sebelum modeling.

# %%
# Cek ringkasan statistik fitur duration
df_ml['duration'].describe()
# Out:
# count    41176.000000
# mean       258.315815
# std        259.305321
# min          0.000000
# 25%        102.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: duration, dtype: float64

# %%
sns.boxplot(x=df_ml['y'], y=df_ml['duration'], palette="pastel")
plt.title("Distribusi Durasi Panggilan terhadap Target")
plt.xlabel("Target (y)")
plt.ylabel("Durasi (detik)")
plt.show()

# %% [markdown]
# **Insight:**
#
# - Terdapat perbedaan yang jelas antara durasi panggilan untuk pelanggan yang menyetujui (`yes`) dan tidak menyetujui (`no`)
# - Ini membuktikan bahwa `duration` sangat informatif secara statistik
# - Namun karena **baru diketahui setelah kontak dilakukan**, fitur ini akan menyebabkan **overfitting dan data leakage**
# - Oleh karena itu, fitur `duration` akan dihapus dari dataset sebelum tahap pelatihan model

# %% [markdown]
# ##### **Pemeriksaan Tipe Data**
#
# Setiap fitur dalam dataset memiliki tipe data tertentu: numerik (integer/float) atau kategorikal (string/object). Kita perlu mengelompokkan fitur-fitur ini karena tipe data menentukan jenis preprocessing yang akan diterapkan:
#
# - Fitur **numerik** akan di-*scale* menggunakan metode seperti `StandardScaler` atau `RobustScaler`
# - Fitur **kategorikal** akan di-*encode* agar dapat digunakan dalam algoritma machine learning
#
# Langkah ini juga akan membantu kita menghindari kesalahan seperti memberi encoding pada fitur numerik atau sebaliknya.

# %%
# Pisahkan target terlebih dahulu
X = df_ml.drop(columns=['y', 'duration'])
y = df_ml['y']

# Deteksi tipe fitur pada X saja
cat_cols = X.select_dtypes(include='object').columns.tolist()
num_cols = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

print(f"Jumlah fitur kategorikal: {len(cat_cols)}")
print(f"Jumlah fitur numerik: {len(num_cols)}")
# Out:
# Jumlah fitur kategorikal: 10
# Jumlah fitur numerik: 9

# %%
# Lihat nama fitur
print("Fitur kategorikal:\n", cat_cols)
print("\nFitur numerik:\n", num_cols)
# Out:
# Fitur kategorikal:
#  ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
#
# Fitur numerik:
#  ['age', 'campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# %% [markdown]
# **Insight:**
#
# - Dataset ini terdiri dari **9 fitur numerik** dan **10 fitur kategorikal**, dengan target variable `y` telah dipisahkan.
# - Fitur-fitur kategorikal seperti `job`, `education`, `contact`, dan `month` merupakan informasi demografis dan administratif yang akan di-*encode* menggunakan teknik encoding.
# - Fitur numerik seperti `age`, `euribor3m`, dan `emp.var.rate` mewakili nilai kontinu dari pelanggan atau ekonomi makro, dan akan diproses menggunakan teknik scaling.
# - Pemisahan ini penting karena:
#   - Model machine learning **tidak bisa langsung menangani string kategorikal**
#   - Beberapa model sensitif terhadap skala numerik (misalnya Logistic Regression)
#
# > Target variable `y` bertipe kategorikal (yes/no) dan akan diproses secara terpisah (misalnya: diubah menjadi label numerik) di tahap akhir preprocessing.

# %% [markdown]
# ##### **Distribusi Target Variable `y`**
#
# Sebelum melatih model klasifikasi, penting untuk memahami distribusi target variable `y` yang menunjukkan apakah seorang pelanggan menyetujui term deposit atau tidak:
#
# - `yes` = pelanggan melakukan term deposit
# - `no` = pelanggan tidak melakukan term deposit
#
# Distribusi ini akan membantu kita menentukan apakah klasifikasi perlu penyesuaian khusus, seperti penggunaan metrik evaluasi khusus untuk data imbalanced atau strategi balancing data.

# %%
target_dist = y.value_counts().to_frame(name='Jumlah')
target_dist['Persentase (%)'] = y.value_counts(normalize=True) * 100

target_dist
# Out:
#      Jumlah  Persentase (%)
# y
# no    36537       88.733728
# yes    4639       11.266272

# %% [markdown]
# **Insight:**
#
# - Dataset memiliki distribusi target yang sangat **imbalanced**, dengan hanya sekitar **11% pelanggan** yang menyetujui term deposit.
# - Kondisi seperti ini dapat menyebabkan model klasifikasi menjadi **bias terhadap kelas mayoritas** (`no`) dan mengabaikan kelas minoritas (`yes`).
# - Karena fokus utama kita adalah **memprediksi pelanggan yang mau berlangganan (`yes`)**, maka perlu:
#   - Menggunakan metrik evaluasi yang sesuai seperti **F1-score** atau **recall**
#   - Mempertimbangkan teknik **resampling** seperti **SMOTE** di tahap modeling
#   - (Nanti) menghitung dampak bisnis dari prediksi salah melalui **custom business metric**

# %% [markdown]
# ## **Outlier Analysis**

# %% [markdown]
# Outlier (nilai ekstrim) dapat mempengaruhi hasil pelatihan model secara signifikan, terutama saat menggunakan teknik scaling seperti `StandardScaler`. Oleh karena itu, kita melakukan eksplorasi outlier pada setiap fitur numerik.
#
# Strategi umum untuk penanganan outlier:
# - **Capping / winsorizing**: membatasi nilai ekstrim ke batas P1/P99
# - **Log-transform**: untuk mengurangi efek lonjakan di distribusi miring
# - **RobustScaler**: alternatif scaling yang tidak sensitif terhadap outlier
# - **Menghapus baris**: jika nilai tidak masuk akal secara domain bisnis
#
# Analisis awal dilakukan dengan visualisasi boxplot dan summary statistik.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Buat boxplot untuk semua fitur numerik
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 12))
axes = axes.flatten()

for i, col in enumerate(num_cols):
    sns.boxplot(data=X, y=col, ax=axes[i], color="skyblue")
    axes[i].set_title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight per Fitur:**
#
# | Fitur             | Outlier? | Analisis                                                                 |
# |------------------|----------|--------------------------------------------------------------------------|
# | `age`            |  Ya    | Ada nilai hingga 98 tahun. Masih masuk akal, tapi minor outlier          |
# | `campaign`       |  Ya    | Sebagian besar data ≤ 5, tapi ada lonjakan hingga 56 (mencurigakan)      |
# | `pdays`          |  Khusus | Nilai 999 berarti belum pernah dihubungi sebelumnya → bukan outlier biasa|
# | `previous`       |  Ya    | Mayoritas = 0, tapi beberapa hingga 7                                    |
# | `emp.var.rate`   |  Tidak | Nilai relatif stabil                                                     |
# | `cons.price.idx` |  Tidak | Distribusi stabil                                                        |
# | `cons.conf.idx`  |  Tidak | Distribusi stabil                                                        |
# | `euribor3m`      |  Sedikit | Distribusi agak miring, ada outlier kecil di atas 5                      |
# | `nr.employed`    |  Tidak | Nilai cukup stabil dan terkonsentrasi                                   |
#
# **Rencana Tindakan:**
#
# - **`campaign`**: Akan dilakukan capping (pembatasan) nilai maksimal di persentil 95 untuk menghindari efek nilai ekstrem seperti 56
# - **`previous`**: Akan dilakukan capping ringan (opsional) untuk mengatasi lonjakan hingga 7
# - **`age`**: Nilai tinggi (>90 tahun) bisa dicapping ringan di P99, atau dibiarkan jika jumlahnya kecil
# - **`euribor3m`**: Tidak akan dicapping, tetapi akan diproses menggunakan `RobustScaler` jika model sensitif terhadap outlier
# - **`pdays`**: Akan direkayasa ulang menjadi fitur kategorikal yang membedakan antara "pernah dihubungi sebelumnya" dan "belum pernah"
#
# Langkah-langkah perbaikan akan diterapkan sebelum tahap modeling dan scaling.

# %% [markdown]
# **Penanganan Outlier**
#
# Setelah analisis visual dan statistik terhadap fitur numerik, kita menerapkan transformasi untuk mereduksi pengaruh nilai ekstrim (outlier) terhadap model. Transformasi dilakukan satu per satu dengan justifikasi yang jelas.
#
# Berikut langkah-langkahnya:

# %% [markdown]
# **Capping Fitur `campaign`**
#
# - `campaign` merepresentasikan jumlah kontak yang dilakukan kepada nasabah dalam satu kampanye.
# - Secara statistik, mayoritas nilai berada di bawah 5, tetapi ada outlier hingga **56 kali**.
# - Nilai ekstrem tersebut jarang terjadi dan berpotensi besar menyesatkan model.
#
# Maka kita akan membatasi nilai `campaign` ke batas **P95** (nilai persentil ke-95).
#
# > Ini menghindari distorsi model tanpa menghapus data apa pun.

# %%
# Cek distribusi campaign
X['campaign'].describe(percentiles=[0.75, 0.95, 0.96, 0.97, 0.99])
# Out:
# count    41176.000000
# mean         2.567879
# std          2.770318
# min          1.000000
# 50%          2.000000
# 75%          3.000000
# 95%          7.000000
# 96%          8.000000
# 97%          9.000000
# 99%         14.000000
# max         56.000000
# Name: campaign, dtype: float64

# %%
# Terapkan capping campaign
import numpy as np

X_capped = X.copy()
campaign_cap = X_capped['campaign'].quantile(0.95)
X_capped['campaign'] = np.where(X_capped['campaign'] > campaign_cap, campaign_cap, X_capped['campaign'])

# %% [markdown]
# **Capping Fitur `previous`**
#
# Alasan Capping:
#
# - 75% data = 0 → mayoritas belum pernah merespon campaign
# - Namun ada lonjakan ke 7 (maksimum)
# - Model bisa terlalu fokus pada minor kasus ekstrem
# - P95 cukup konservatif dan membantu hilangkan lonjakan tanpa hilangkan info penting

# %%
X['previous'].describe(percentiles=[0.75, 0.95, 0.97, 0.99])
# Out:
# count    41176.000000
# mean         0.173013
# std          0.494964
# min          0.000000
# 50%          0.000000
# 75%          0.000000
# 95%          1.000000
# 97%          1.000000
# 99%          2.000000
# max          7.000000
# Name: previous, dtype: float64

# %%
previous_cap = X_capped['previous'].quantile(0.95)
X_capped['previous'] = np.where(X_capped['previous'] > previous_cap, previous_cap, X_capped['previous'])

# %% [markdown]
# **Capping Fitur `age`**
#
# Alasan Capping:
#
# - Beberapa nilai mendekati 100 tahun
# - Masih masuk akal, tapi bisa mengganggu scaling untuk model sensitif
# - Capping di P99 untuk jaga skala

# %%
age_cap = X_capped['age'].quantile(0.99)
X_capped['age'] = np.where(X_capped['age'] > age_cap, age_cap, X_capped['age'])

# %%
# Hitung proporsi nilai pdays
pdays_counts = df_ml['pdays'].value_counts()
total = len(df_ml)

pdays_prop = pd.DataFrame({
    'Jumlah': pdays_counts,
    'Proporsi (%)': (pdays_counts / total * 100).round(2)
})

display(pdays_prop.sort_index(ascending=False).head(10))  # tampilkan 10 teratas

# Buat fitur kategorikal baru dari pdays
X_capped['pdays_grouped'] = np.where(df_ml['pdays'] == 999, 'never_contacted', 'contacted_before')

# Drop kolom pdays asli jika sudah tidak digunakan
X_capped.drop(columns='pdays', inplace=True)
# Out:
#        Jumlah  Proporsi (%)
# pdays
# 999     39661         96.32
# 27          1          0.00
# 26          1          0.00
# 25          1          0.00
# 22          3          0.01
# 21          2          0.00
# 20          1          0.00
# 19          3          0.01
# 18          7          0.02
# 17          8          0.02

# %% [markdown]
# **Insight:**
# Hanya ~3.7% dari data yang benar-benar mewakili "pernah dihubungi sebelumnya", artinya distribusi pdays sangat tidak seimbang.
# Kalau tetap kita perlakukan sebagai variabel numerik, maka model bisa belajar dari 96% data yang artinya "tidak pernah" tapi hanya ~4% data sisanya yang punya variasi numerik → noise, bukan sinyal kuat
#
# **Penanganan:**
# Karena 96% pelanggan belum pernah dihubungi, maka mengubah pdays menjadi fitur kategorikal ['never_contacted', 'contacted_before'] adalah keputusan yang tepat.
# Ini menghindari distorsi karena nilai palsu 999, dan membuat data lebih stabil serta mudah dipahami model.

# %% [markdown]
# **Value kolom kategorikal tidak konsisten**
#
# Saat inspeksi manual terhadap kolom `job`, ditemukan satu nilai yang tidak konsisten: `'admin.'` menggunakan titik, sedangkan semua label lain tidak. Untuk konsistensi dan mencegah redundant one-hot encoding, kita ubah nilai `'admin.'` menjadi `'admin'`.

# %%
X_capped['job'] = X_capped['job'].replace('admin.', 'admin')
print("Nilai unik kolom job:", X_capped['job'].unique())
# Out:
# Nilai unik kolom job: ['housemaid' 'services' 'admin' 'blue-collar' 'technician' 'retired'
#  'management' 'unemployed' 'self-employed' 'unknown' 'entrepreneur'
#  'student']

# %% [markdown]
# **Encoding Target (`y`):**
#
# Kolom `y` merupakan target yang masih dalam bentuk kategorikal: `'yes'` dan `'no'`. Kita ubah menjadi format biner (`1` untuk `'yes'`, `0` untuk `'no'`) agar bisa digunakan oleh model klasifikasi.

# %%
y_encoded = df_ml['y'].map({'no': 0, 'yes': 1})
print("Distribusi target (encoded):")
print(y_encoded.value_counts())
# Out:
# Distribusi target (encoded):
# y
# 0    36537
# 1     4639
# Name: count, dtype: int64

# %%
# Deteksi ulang tipe data setelah semua transformasi
cat_cols = X_capped.select_dtypes(include='object').columns.tolist()
num_cols = X_capped.select_dtypes(include='number').columns.tolist()

# Tampilkan daftar kolom final
print("Fitur kategorikal:", cat_cols)
print("Fitur numerik:", num_cols)
# Out:
# Fitur kategorikal: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'pdays_grouped']
# Fitur numerik: ['age', 'campaign', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# %% [markdown]
# ## **Methodology (Modeling/Analysis)**
#
# **Model yang akan diuji**
#
# Berdasarkan karakteristik dataset ini (klasifikasi biner, imbalance, data tabular), maka model-model berikut dipilih untuk dibandingkan:
#
# - **Logistic Regression** → baseline model yang mudah diinterpretasi
# - **Random Forest** → model robust berbasis pohon, kuat untuk dataset tabular
# - **XGBoost** → boosting model dengan performa tinggi di kompetisi data
# - **K-Nearest Neighbors (KNN)** → pembanding, sensitif terhadap scaling & imbalance
#
# Model-model ini dipilih karena mewakili beragam pendekatan dan kompleksitas.

# %% [markdown]
# **Strategi Evaluasi: Train-Test Split + Stratification**
#
# Untuk membandingkan model secara adil, kita menggunakan pendekatan:
#
# - **Stratified train-test split**:
#   - Menjaga proporsi target (`yes` ≈ 11%)
#   - Memastikan model tidak bias karena ketimpangan distribusi
# - Evaluasi dilakukan di test set menggunakan metrik:
#   - Accuracy, Precision, Recall, F1-score, ROC AUC

# %%
X_capped_unk=X_capped.copy()
y_encoded_unk=y_encoded.copy()

# %%
X_capped_unk
# Out:
#         age          job  marital            education  default housing loan  \
# 0      56.0    housemaid  married             basic.4y       no      no   no
# 1      57.0     services  married          high.school  unknown      no   no
# 2      37.0     services  married          high.school       no     yes   no
# 3      40.0        admin  married             basic.6y       no      no   no
# 4      56.0     services  married          high.school       no      no  yes
# ...     ...          ...      ...                  ...      ...     ...  ...
# 41183  71.0      retired  married  professional.course       no     yes   no
# 41184  46.0  blue-collar  married  professional.course       no      no   no
# 41185  56.0      retired  married    university.degree       no     yes   no
# 41186  44.0   technician  married  professional.course       no      no   no
# 41187  71.0      retired  married  professional.course       no     yes   no
#
# ...

# %%
X_capped_unk.replace('unknown', np.nan, inplace=True)

# %%
idx = X_capped_unk[X_capped_unk.isna().any(axis=1)].index
len(idx)
# Out:
# 10698

# %%
X_capped_unk.dropna(inplace=True)
y_encoded_unk.drop(index=idx, inplace=True)

# %%
from sklearn.model_selection import train_test_split

# Split data dengan stratifikasi berdasarkan target
X_train, X_test, y_train, y_test = train_test_split(
    X_capped, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

# Cek proporsi target setelah split
print("Train set target distribution:")
print(y_train.value_counts(normalize=True).round(4))

print("\nTest set target distribution:")
print(y_test.value_counts(normalize=True).round(4))

# Split data dengan stratifikasi berdasarkan target
X_train_unk, X_test_unk, y_train_unk, y_test_unk = train_test_split(
    X_capped_unk, y_encoded_unk, test_size=0.2, random_state=42, stratify=y_encoded_unk
)

# Cek proporsi target setelah split
print("Train set target distribution:")
print(y_train_unk.value_counts(normalize=True).round(4))

print("\nTest set target distribution:")
print(y_test_unk.value_counts(normalize=True).round(4))
# Out:
# Train set target distribution:
# y
# 0    0.8873
# 1    0.1127
# Name: proportion, dtype: float64
#
# Test set target distribution:
# y
# 0    0.8873
# 1    0.1127
# Name: proportion, dtype: float64
# Train set target distribution:
# y
# 0    0.8734
# 1    0.1266
# Name: proportion, dtype: float64
#
# Test set target distribution:
# y
# 0    0.8734
# 1    0.1266
# Name: proportion, dtype: float64

# %% [markdown]
# ### Business Metric
#
# Berdasarkan `Metriks Evaluasi` yang ada dibagian `Business Understanding`, kami akan membuat sebuah metriks yang dapat menilai baik atau buruknya hasil dari machine learning (membandingkan untungnya) yang berbasis dari rumus berikut:
#
#     Rata-rata investasi:
#     - `2695 Euro`
#
#     Keuntungan per nasabah (Kelas 1):
#     - `Nominal deposit * (Bunga Pinjaman - Bunga deposit)` -> `2695 * (4.98%-0.10%) = 131 Euro per tahun`
#
#     Potensi Keuntungan(berdasarkan jumlah nasabah yang ada pada dataset):
#     - `131 Euro * 41188 = 5,395,628 Euro` -> apabila semua nasabah melakukan term deposit
#
#     Kerugian:
#     - Type 0 Error -> Apabila kehilangan nasabah yang akan mendepositkan uang sejumlah `2695 Euro`, maka bank akan mendapat kerugian sebesar `131 Euro` dari tiap nasabah yang hilang.
#     - Type 1 Error -> Apabila bank mengeluarkan biaya untuk nasabah yang tidak melakukan term deposit, maka bank akan mengeluarkan biaya untuk setiap panggilannya. Kita asumsikan jumlah panggilan rata rata per nasabah adalah 5x panggilan berdasarkan data, maka untuk setiap panggilan yang tidak terkonversi, bank akan merugi sekitar `18 Euro` uro`
#
# dari rumus ini kami melakukan normalisasi agar hasil dari business metric ini mengeluarkan nilai mulai dari 0 hingga 1 yang menandakan seberapa signifikannya model tersebut dalam meningkatkan keuntungan apabila dibandingkan dengan tanpa model.

# %% [markdown]
# ### Alasan Penggunaan Classification Metric dan Business Metric dalam Evaluasi Model
#
# Dalam proyek prediksi term deposit bank, kami menggunakan pendekatan evaluasi bertingkat yang dimulai dengan **classification metric (F2-Score)** dan diakhiri dengan **business metric** sebagai penentu akhir. Dokumen ini menjelaskan alasan filosofis dan praktis di balik pendekatan ini.
#
# ### 1. Mengapa Menggunakan F2-Score Sebagai Eliminasi Pertama?
#
# ### 1.1 Karakteristik F2-Score
# F2-Score memberikan bobot lebih tinggi pada **recall** dibandingkan precision, dengan formula:
# ```
# F2 = (1 + 2²) × (precision × recall) / (2² × precision + recall)
# ```
#
# ### 1.2 Konteks Bisnis Bank
# Dalam konteks term deposit bank:
# - **False Negative (FN)**: Nasabah yang diprediksi tidak akan berlangganan padahal sebenarnya akan berlangganan
# - **False Positive (FP)**: Nasabah yang diprediksi akan berlangganan padahal sebenarnya tidak akan berlangganan
#
# **Mengapa FN lebih kritis?**
# - Kehilangan nasabah potensial yang sebenarnya tertarik
# - Opportunity cost yang tinggi
# - Dampak jangka panjang terhadap revenue
#
# ### 1.3 F2-Score sebagai Filter Awal
# F2-Score digunakan sebagai **filter teknis** untuk:
# - Menghilangkan model dengan performa recall yang buruk
# - Memastikan model dapat mengidentifikasi sebagian besar nasabah potensial
# - Memberikan baseline minimum untuk evaluasi lanjutan
#
# ## 2. Mengapa Business Metric Sebagai Penentu Akhir?
#
# ### 2.1 Definisi Business Metric
# Business metric dalam proyek ini mengukur dampak finansial langsung:
# ```python
# def business_metric(y_true, y_pred):
#     # Menghitung net profit berdasarkan prediksi
#     # Mempertimbangkan cost dan revenue
#     return normalized_profit_score
# ```
#
# ### 2.2 Keunggulan Business Metric
#
# #### 2.2.1 Alignment dengan Tujuan Bisnis
# - **Classification metrics**: Mengukur akurasi teknis model
# - **Business metrics**: Mengukur dampak finansial langsung terhadap bisnis
#
# #### 2.2.2 Interpretasi yang Jelas
# - F2-Score: "Model ini 85% akurat dalam mengidentifikasi nasabah potensial"
# - Business Metric: "Model ini meningkatkan profit bank sebesar 52.643 Euro"
#
# #### 2.2.3 Stakeholder Communication
# - Mudah dipahami oleh non-technical stakeholders
# - Memberikan justifikasi finansial yang jelas
# - Memudahkan pengambilan keputusan bisnis
#
# ### 2.3 Business Metric sebagai Final Arbiter
#
# #### 2.3.1 Trade-off Optimization
# Business metric mempertimbangkan:
# - **Revenue**: Keuntungan dari nasabah yang berhasil dikonversi
# - **Cost**: Biaya kampanye marketing yang tidak efektif
# - **Risk**: Dampak prediksi yang salah
#
# #### 2.3.2 Real-world Impact
# - Model dengan F2-Score tinggi tapi business metric rendah = tidak optimal
# - Model dengan F2-Score sedang tapi business metric tinggi = lebih berharga
#
# ## 3. Mengapa Tidak Menggunakan Satu Metric Saja?
#
# ### 3.1 Keterbatasan Classification Metric Saja
#
# #### 3.1.1 Tidak Mempertimbangkan Cost-Benefit
# - F2-Score tidak membedakan antara FP dan FN dari segi biaya
# - Tidak mempertimbangkan nilai ekonomi dari setiap prediksi
#
# #### 3.1.2 Tidak Ada Alignment dengan Business Goals
# - Model bisa akurat secara teknis tapi tidak menguntungkan
# - Tidak ada koneksi langsung dengan ROI
#
# ### 3.2 Keterbatasan Business Metric Saja
#
# #### 3.2.1 Kompleksitas Perhitungan
# - Business metric memerlukan asumsi dan parameter yang kompleks
# - Sulit untuk dioptimasi secara langsung dalam training
#
# #### 3.2.2 Risiko Overfitting
# - Optimasi langsung terhadap business metric bisa menyebabkan overfitting
# - Model mungkin tidak generalizable
#
# #### 3.2.3 Interpretasi Teknis yang Sulit
# - Sulit untuk debugging model performance
# - Tidak memberikan insight tentang precision/recall trade-off
#
# ### 4. Flow Evaluasi yang Optimal
#
# ### 4.1 Tahap 1: Classification Metric (F2-Score)
# ```
# Tujuan: Filter teknis
# Input: Semua model yang sudah di-train
# Output: Model dengan F2-Score > threshold minimum
# Alasan: Memastikan model memiliki kemampuan dasar yang baik
# ```
#
# ### 4.2 Tahap 2: Business Metric
# ```
# Tujuan: Seleksi final berdasarkan dampak bisnis
# Input: Model yang lolos filter F2-Score
# Output: Model dengan business metric tertinggi
# Alasan: Memilih model yang memberikan nilai bisnis terbaik
# ```
#
# ## 5. Contoh Praktis dari Proyek
#
# ### 5.1 Hasil Evaluasi
# - **Model A**: F2-Score = 0.85, Business Score = 0.45
# - **Model B**: F2-Score = 0.75, Business Score = 0.72
#
# ### 5.2 Analisis
# - Model A lebih akurat secara teknis
# - Model B memberikan dampak bisnis yang lebih besar
# - **Keputusan**: Pilih Model B karena business metric sebagai penentu akhir
#
# ## 6. Kesimpulan
#
# ### 6.1 Pendekatan Bertingkat
# 1. **Classification metric (F2-Score)** sebagai filter teknis
# 2. **Business metric** sebagai penentu akhir
#
# ### 6.2 Keuntungan Pendekatan Ini
# - **Efisiensi**: Menghindari evaluasi business metric pada model yang performanya buruk
# - **Akurasi**: Memastikan model yang dipilih memiliki kemampuan teknis yang memadai
# - **Alignment**: Memastikan model yang dipilih memberikan nilai bisnis yang optimal
#
# ### 6.3 Best Practice
# - Gunakan classification metric untuk screening awal
# - Gunakan business metric untuk final decision untuk selanjutnya dilakukan hyperparameter tuning dan lain-lain

# %% [markdown]
# ### Definisikan Business Metric:

# %%
from sklearn.metrics import confusion_matrix, make_scorer

def business_metric(y, y_pred):
    tn, fp, fn, tp = confusion_matrix(y, y_pred).ravel()
    total = tn + fp + fn + tp
    raw_score = ((tp*131 - (fp+tp)*18) - ((tp+fn)*131 - total*18)) / total
    # Normalisasi skor ke 0–1
    min_score = -14.52
    max_score = 18.0
    normalized_score = (raw_score - min_score) / (max_score - min_score)
    return normalized_score

business_score = make_scorer(business_metric, greater_is_better=True)

# %% [markdown]
# ## Base Model tanpa Resampler

# %%
### Base Model tanpa Resampler (Sebagai Pembanding)
print("🔍 Menjalankan Base Model tanpa Resampler untuk Bukti Ketidakseimbangan Data")
print("=" * 70)

# === Import Libraries yang Diperlukan ===
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
import pandas as pd
import numpy as np

# === Setup Cross Validation dan Scoring ===
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scoring = {
    'accuracy': 'accuracy',
    'f1': 'f1',
    'precision': 'precision',
    'recall': 'recall'
}

# === Define Categorical and Numerical Columns ===
cat_cols = X_train.select_dtypes(include='object').columns.tolist()
num_cols = X_train.select_dtypes(include='number').columns.tolist()

print(f"Categorical columns: {cat_cols}")
print(f"Numerical columns: {num_cols}")

# === Create Preprocessor ===
preprocessor = ColumnTransformer([
    ('num', RobustScaler(), num_cols),
    ('cat', OneHotEncoder(drop='first', sparse_output=False), cat_cols)
], remainder='passthrough')

# === Base Model tanpa Resampler ===
base_models = [
    ('Logistic Regression', LogisticRegression(random_state=42)),
    ('Random Forest', RandomForestClassifier(random_state=42)),
    ('XGBoost', XGBClassifier(random_state=42)),
    ('LightGBM', LGBMClassifier(random_state=42))
]

base_results = []

for model_name, model in base_models:
    print(f"\n🔍 Testing: {model_name}")
    
    # Pipeline tanpa resampler
    pipe_base = Pipeline([
        ('preprocessor', preprocessor),
        ('classifier', model)
    ])
    
    # Cross validation
    cv_scores = cross_validate(pipe_base, X_train, y_train, 
                              cv=skf, scoring=scoring, n_jobs=-1)
    
    # Fit model
    pipe_base.fit(X_train, y_train)
    
    # Predictions
    y_pred_base = pipe_base.predict(X_test)
    
    # Metrics
    accuracy_base = accuracy_score(y_test, y_pred_base)
    f1_base = f1_score(y_test, y_pred_base)
    precision_base = precision_score(y_test, y_pred_base)
    recall_base = recall_score(y_test, y_pred_base)
    
    # Classification report
    print(f"Accuracy: {accuracy_base:.4f}")
    print(f"F1-Score: {f1_base:.4f}")
    print(f"Precision: {precision_base:.4f}")
    print(f"Recall: {recall_base:.4f}")
    
    # Confusion matrix
    cm_base = confusion_matrix(y_test, y_pred_base)
    print(f"\nConfusion Matrix:")
    print(cm_base)
    
    # Store results
    base_results.append({
        'Model': model_name,
        'Accuracy': accuracy_base,
        'F1-Score': f1_base,
        'Precision': precision_base,
        'Recall': recall_base,
        'CV_Accuracy_Mean': cv_scores['test_accuracy'].mean(),
        'CV_F1_Mean': cv_scores['test_f1'].mean()
    })

# Convert to DataFrame
base_df = pd.DataFrame(base_results)
print("\n" + "=" * 70)
print("�� HASIL BASE MODEL TANPA RESAMPLER")
print("=" * 70)
print(base_df.round(4))

print("\n🔍 KESIMPULAN: Base model menunjukkan performa yang buruk pada kelas minoritas")
print("   Ini membuktikan bahwa resampler memang diperlukan!")
print("=" * 70)
# Out:
# 🔍 Menjalankan Base Model tanpa Resampler untuk Bukti Ketidakseimbangan Data
# ...
# Categorical columns: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome', 'pdays_grouped']
# Numerical columns: ['age', 'campaign', 'previous', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']
#
# 🔍 Testing: Logistic Regression
# Accuracy: 0.8983
# F1-Score: 0.3131
# Precision: 0.6541
# Recall: 0.2058
#
# Confusion Matrix:
# [[7207  101]
#  [ 737  191]]
#
# 🔍 Testing: Random Forest
# Accuracy: 0.8911
# F1-Score: 0.3643
# Precision: 0.5321
# Recall: 0.2769
#
# Confusion Matrix:
# [[7082  226]
#  [ 671  257]]
#
# 🔍 Testing: XGBoost
# Accuracy: 0.8972
# F1-Score: 0.3767
# Precision: 0.5940
# Recall: 0.2759
#
# Confusion Matrix:
# [[7133  175]
#  [ 672  256]]
#
# 🔍 Testing: LightGBM
# [LightGBM] [Info] Number of positive: 3711, number of negative: 29229
# ...

# %% [markdown]
# ### Pipeline Modeling dengan Resampler
#
# Karena target kita tidak seimbang (`yes` hanya ~11%), kita perlu menangani imbalance agar model tidak bias ke kelas mayoritas. Untuk itu, kita menggunakan beberapa resampler untuk di uji coba:
# - smote
# - random over sampler (ROS)
# - random under sampler (RUS)
# - nearmiss
# - smotenc
#
# #### Classification Metric
#
# Secara konteks bisnis keuntungan yang didapat oleh bank apabila berhasil mengkonversikan nasabah adalah sebesar 131 Euro dan biaya operasional untuk menghubungi nasabah adalah 18 Euro. Berdasarkan informasi ini, kita dapat menyimpulkan bahwa setiap 1 nasabah yang terkonversi dapat mengkompensasi biaya telepon yang dilakukan untuk 8 nasabah. ini artinya untuk meningkatkan keuntungan kita memiliki 2 opsi yaitu meningkatkan konversi nasabah (TP) dengan meraih sebanyak mungkin nasabah potensial (FN) atau menekan biaya telepon yang tidak berujung konversi (FP)
#
# Untuk memilih model yang memiliki performance yang baik pertama-tama kami akan menggunakan `F2 Score` untuk dijadikan acuan. F2 merupakan metric yang menitik beratkan pada recall sehingga dapat mengurangi False Negative karena dalam konteks bisnis ini FN (Kehilangan Nasabah Potensial) memiliki bobot yang besar sehingga kita dapat memaksimalkan keuntungan.

# %% [markdown]
# #### Without Unknown

# %%
from imblearn.over_sampling import SMOTE, RandomOverSampler, SMOTENC
from imblearn.under_sampling import RandomUnderSampler, NearMiss
from imblearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, fbeta_score

import lightgbm as lgb
import pandas as pd
import numpy as np
import warnings

# ✅ Hilangkan warning XGBoost & FutureWarning
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# === 1) Pisahkan kolom berdasarkan tipe ===
ordinal_cols = ['education']
nominal_cols = ['job', 'marital', 'default', 'month', 'day_of_week', 'housing', 'loan', 'contact', 'poutcome', 'pdays_grouped']

# === 2) Preprocessor dengan remainder='passthrough' ===
numeric_pipeline = RobustScaler()
ordinal_pipeline = OrdinalEncoder()
nominal_pipeline = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

preprocessor = ColumnTransformer([
    ('num', numeric_pipeline, num_cols),
    ('ordinal', ordinal_pipeline, ordinal_cols),
    ('nominal', nominal_pipeline, nominal_cols)
], remainder='passthrough')

# === 3) Model dan resampler ===
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    "KNN": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(max_depth=5, random_state=0),
    "LGBM": lgb.LGBMClassifier(random_state=0),
    "Gradient Boost":GradientBoostingClassifier(random_state=0),
}

resamplers = [ "SMOTENC", "SMOTE", "RandomOverSampler", "RandomUnderSampler", "NearMiss"]

# === 4) Define StratifiedKFold dan scoring ===
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)  # ✅ Define skf
scoring = {
            'accuracy': 'accuracy',
            'precision': 'precision',
            'recall': 'recall',
            'f1': 'f1',
            'roc_auc': 'roc_auc',
            'business': business_score,
            'f2' : make_scorer(fbeta_score, beta=2, pos_label=1)
            }

# === 5) Loop modelling yang diperbaiki ===
results = []

for resampler_name in resamplers:
    print(f"\n🔁 Resampler: {resampler_name}")

    for model_name, model in models.items():
        print(f"   ⚙️ Model: {model_name}")

        if resampler_name == "SMOTENC":
            # === Pipeline untuk SMOTENC ===
            # 1. Preprocess data untuk mendapatkan feature names
            X_processed = preprocessor.fit_transform(X_train_unk)
            feature_names = preprocessor.get_feature_names_out()
            
            # 2. Buat mask untuk kolom kategorikal (ordinal + nominal)
            categorical_mask = []
            for i, name in enumerate(feature_names):
                if any(col in name for col in ordinal_cols + nominal_cols):
                    categorical_mask.append(i)
            
            # 3. Pipeline dengan SMOTENC
            pipe_smotenc = Pipeline([
                ('preprocessor', preprocessor),
                ('resampler', SMOTENC(categorical_features=categorical_mask, random_state=42)),
                ('model', model)
            ])
            
            # 4. Cross validation
            cv_scores = cross_validate(pipe_smotenc, X_train_unk, y_train_unk, cv=skf, scoring=scoring, n_jobs=-1)
            
            # 5. Fit dan predict
            pipe_smotenc.fit(X_train_unk, y_train_unk)
            y_pred_unk = pipe_smotenc.predict(X_test_unk)
            y_proba_unk = pipe_smotenc.predict_proba(X_test_unk)[:, 1] if hasattr(pipe_smotenc.named_steps['model'], "predict_proba") else None

            results.append({
                'Resampler': resampler_name,
                'Model': model_name,
                'CV Accuracy Mean': cv_scores['test_accuracy'].mean(),
                'CV F1 Mean': cv_scores['test_f1'].mean(),
                'CV Recall Mean': cv_scores['test_recall'].mean(),
                'CV Precision Mean': cv_scores['test_precision'].mean(),
                'CV ROC AUC Mean': cv_scores['test_roc_auc'].mean(),
                'Test Accuracy': accuracy_score(y_test_unk, y_pred_unk),
                'Test Precision': precision_score(y_test_unk, y_pred_unk),
                'Test Recall': recall_score(y_test_unk, y_pred_unk),
                'Test F1': f1_score(y_test_unk, y_pred_unk),
                'Test F2' : fbeta_score(y_test_unk, y_pred_unk, beta=2, pos_label=1),
                'Test ROC AUC': roc_auc_score(y_test_unk, y_proba_unk) if y_proba_unk is not None else None
            })

        else:
            # === Pipeline untuk resampler normal ===
            if resampler_name == "SMOTE":
                resampler = SMOTE(random_state=42)
            elif resampler_name == "RandomOverSampler":
                resampler = RandomOverSampler(random_state=42)
            elif resampler_name == "RandomUnderSampler":
                resampler = RandomUnderSampler(random_state=42)
            elif resampler_name == "NearMiss":
                resampler = NearMiss()
            else:
                raise ValueError("Resampler tidak dikenal")

            pipe = Pipeline([
                ('preprocessor', preprocessor),
                ('resampler', resampler),
                ('model', model)
            ])

            cv_scores = cross_validate(pipe, X_train_unk, y_train_unk, cv=skf, scoring=scoring, n_jobs=-1)

            pipe.fit(X_train_unk, y_train_unk)
            y_pred_unk = pipe.predict(X_test_unk)
            y_proba_unk = pipe.predict_proba(X_test_unk)[:, 1] if hasattr(pipe.named_steps['model'], "predict_proba") else None

            results.append({
                'Resampler': resampler_name,
                'Model': model_name,
                'CV Accuracy Mean': cv_scores['test_accuracy'].mean(),
                'CV F1 Mean': cv_scores['test_f1'].mean(),
                'CV Recall Mean': cv_scores['test_recall'].mean(),
                'CV Precision Mean': cv_scores['test_precision'].mean(),
                'CV ROC AUC Mean': cv_scores['test_roc_auc'].mean(),
                'Test Accuracy': accuracy_score(y_test_unk, y_pred_unk),
                'Test Precision': precision_score(y_test_unk, y_pred_unk),
                'Test Recall': recall_score(y_test_unk, y_pred_unk),
                'Test F1': f1_score(y_test_unk, y_pred_unk),
                'Test F2': fbeta_score(y_test_unk, y_pred_unk, beta=2, pos_label=1),
                'Test ROC AUC': roc_auc_score(y_test_unk, y_proba_unk) if y_proba_unk is not None else None
            })

# === Output ===
results_df_unk = pd.DataFrame(results).reset_index(drop=True)
# Out:
# 🔁 Resampler: SMOTENC
#    ⚙️ Model: Logistic Regression
#    ⚙️ Model: Random Forest
#    ⚙️ Model: XGBoost
#    ⚙️ Model: KNN
#    ⚙️ Model: Decision Tree
#    ⚙️ Model: LGBM
# [LightGBM] [Info] Number of positive: 21296, number of negative: 21296
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1796
# [LightGBM] [Info] Number of data points in the train set: 42592, number of used features: 49
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#    ⚙️ Model: Gradient Boost
#
# 🔁 Resampler: SMOTE
#    ⚙️ Model: Logistic Regression
#    ⚙️ Model: Random Forest
#    ⚙️ Model: XGBoost
#    ⚙️ Model: KNN
#    ⚙️ Model: Decision Tree
#    ⚙️ Model: LGBM
# [LightGBM] [Info] Number of positive: 21296, number of negative: 21296
# ...

# %% [markdown]
# #### With Unknown

# %%
# === 1) Pisahkan kolom berdasarkan tipe ===
ordinal_cols = ['education']
nominal_cols = ['job', 'marital', 'default', 'month', 'day_of_week', 'housing', 'loan', 'contact', 'poutcome', 'pdays_grouped']

# === 2) Preprocessor dengan remainder='passthrough' ===
numeric_pipeline = RobustScaler()
ordinal_pipeline = OrdinalEncoder()
nominal_pipeline = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

preprocessor = ColumnTransformer([
    ('num', numeric_pipeline, num_cols),
    ('ordinal', ordinal_pipeline, ordinal_cols),
    ('nominal', nominal_pipeline, nominal_cols)
], remainder='passthrough')

# === 3) Model dan resampler ===
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    "KNN": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(max_depth=5, random_state=0),
    "LGBM": lgb.LGBMClassifier(random_state=0),
    "Gradient Boost":GradientBoostingClassifier(random_state=0),
}

resamplers = [ "SMOTENC", "SMOTE", "RandomOverSampler", "RandomUnderSampler", "NearMiss"]

# === 4) Define StratifiedKFold dan scoring ===
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)  # ✅ Define skf
scoring = {
            'accuracy': 'accuracy',
            'precision': 'precision',
            'recall': 'recall',
            'f1': 'f1',
            'roc_auc': 'roc_auc',
            'business': business_score,
            'f2' : make_scorer(fbeta_score, beta=2, pos_label=1)
            }

# === 5) Loop modelling yang diperbaiki ===
results = []

for resampler_name in resamplers:
    print(f"\n🔁 Resampler: {resampler_name}")

    for model_name, model in models.items():
        print(f"   ⚙️ Model: {model_name}")

        if resampler_name == "SMOTENC":
            # === Pipeline untuk SMOTENC ===
            # 1. Preprocess data untuk mendapatkan feature names
            X_processed = preprocessor.fit_transform(X_train)
            feature_names = preprocessor.get_feature_names_out()
            
            # 2. Buat mask untuk kolom kategorikal (ordinal + nominal)
            categorical_mask = []
            for i, name in enumerate(feature_names):
                if any(col in name for col in ordinal_cols + nominal_cols):
                    categorical_mask.append(i)
            
            # 3. Pipeline dengan SMOTENC
            pipe_smotenc = Pipeline([
                ('preprocessor', preprocessor),
                ('resampler', SMOTENC(categorical_features=categorical_mask, random_state=42)),
                ('model', model)
            ])
            
            # 4. Cross validation
            cv_scores = cross_validate(pipe_smotenc, X_train, y_train, cv=skf, scoring=scoring, n_jobs=-1)
            
            # 5. Fit dan predict
            pipe_smotenc.fit(X_train, y_train)
            y_pred = pipe_smotenc.predict(X_test)
            y_proba = pipe_smotenc.predict_proba(X_test)[:, 1] if hasattr(pipe_smotenc.named_steps['model'], "predict_proba") else None

            results.append({
                'Resampler': resampler_name,
                'Model': model_name,
                'CV Accuracy Mean': cv_scores['test_accuracy'].mean(),
                'CV F1 Mean': cv_scores['test_f1'].mean(),
                'CV Recall Mean': cv_scores['test_recall'].mean(),
                'CV Precision Mean': cv_scores['test_precision'].mean(),
                'CV ROC AUC Mean': cv_scores['test_roc_auc'].mean(),
                'Test Accuracy': accuracy_score(y_test, y_pred),
                'Test Precision': precision_score(y_test, y_pred),
                'Test Recall': recall_score(y_test, y_pred),
                'Test F1': f1_score(y_test, y_pred),
                'Test F2' : fbeta_score(y_test, y_pred, beta=2, pos_label=1),
                'Test ROC AUC': roc_auc_score(y_test, y_proba) if y_proba is not None else None
            })

        else:
            # === Pipeline untuk resampler normal ===
            if resampler_name == "SMOTE":
                resampler = SMOTE(random_state=42)
            elif resampler_name == "RandomOverSampler":
                resampler = RandomOverSampler(random_state=42)
            elif resampler_name == "RandomUnderSampler":
                resampler = RandomUnderSampler(random_state=42)
            elif resampler_name == "NearMiss":
                resampler = NearMiss()
            else:
                raise ValueError("Resampler tidak dikenal")

            pipe = Pipeline([
                ('preprocessor', preprocessor),
                ('resampler', resampler),
                ('model', model)
            ])

            cv_scores = cross_validate(pipe, X_train, y_train, cv=skf, scoring=scoring, n_jobs=-1)

            pipe.fit(X_train, y_train)
            y_pred = pipe.predict(X_test)
            y_proba = pipe.predict_proba(X_test)[:, 1] if hasattr(pipe.named_steps['model'], "predict_proba") else None

            results.append({
                'Resampler': resampler_name,
                'Model': model_name,
                'CV Accuracy Mean': cv_scores['test_accuracy'].mean(),
                'CV F1 Mean': cv_scores['test_f1'].mean(),
                'CV Recall Mean': cv_scores['test_recall'].mean(),
                'CV Precision Mean': cv_scores['test_precision'].mean(),
                'CV ROC AUC Mean': cv_scores['test_roc_auc'].mean(),
                'Test Accuracy': accuracy_score(y_test, y_pred),
                'Test Precision': precision_score(y_test, y_pred),
                'Test Recall': recall_score(y_test, y_pred),
                'Test F1': f1_score(y_test, y_pred),
                'Test F2': fbeta_score(y_test, y_pred, beta=2, pos_label=1),
                'Test ROC AUC': roc_auc_score(y_test, y_proba) if y_proba is not None else None
            })

# === Output ===
results_df = pd.DataFrame(results).reset_index(drop=True)
# Out:
# 🔁 Resampler: SMOTENC
#    ⚙️ Model: Logistic Regression
#    ⚙️ Model: Random Forest
#    ⚙️ Model: XGBoost
#    ⚙️ Model: KNN
#    ⚙️ Model: Decision Tree
#    ⚙️ Model: LGBM
# [LightGBM] [Info] Number of positive: 29229, number of negative: 29229
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002246 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1982
# [LightGBM] [Info] Number of data points in the train set: 58458, number of used features: 55
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#    ⚙️ Model: Gradient Boost
#
# 🔁 Resampler: SMOTE
#    ⚙️ Model: Logistic Regression
#    ⚙️ Model: Random Forest
#    ⚙️ Model: XGBoost
#    ⚙️ Model: KNN
#    ⚙️ Model: Decision Tree
#    ⚙️ Model: LGBM
# [LightGBM] [Info] Number of positive: 29229, number of negative: 29229
# ...

# %%
# Tanpa unknown
results_df_unk.sort_values('Test F2', ascending=False).head(5)
# Out:
#              Resampler                Model  CV Accuracy Mean  CV F1 Mean  \
# 19   RandomOverSampler                 LGBM          0.834181    0.496670
# 20   RandomOverSampler       Gradient Boost          0.820482    0.484641
# 26  RandomUnderSampler                 LGBM          0.805677    0.468640
# 27  RandomUnderSampler       Gradient Boost          0.815684    0.481517
# 21  RandomUnderSampler  Logistic Regression          0.810927    0.472158
#
#     CV Recall Mean  CV Precision Mean  CV ROC AUC Mean  Test Accuracy  \
# 19        0.646139           0.403505         0.805595       0.828740
# 20        0.666554           0.380904         0.811139       0.817913
# 26        0.676922           0.358414         0.802797       0.796752
# 27        0.676271           0.373939         0.810261       0.805610
# 21        0.667845           0.365394         0.801755       0.802822
#
#     Test Precision  Test Recall   Test F1   Test F2  Test ROC AUC
# ...

# %%
# Dengan unknown
results_df.sort_values('Test F2', ascending=False).head(5)
# Out:
#              Resampler                Model  CV Accuracy Mean  CV F1 Mean  \
# 19   RandomOverSampler                 LGBM          0.844414    0.469947
# 20   RandomOverSampler       Gradient Boost          0.831967    0.458712
# 27  RandomUnderSampler       Gradient Boost          0.826412    0.453136
# 26  RandomUnderSampler                 LGBM          0.815422    0.442192
# 14   RandomOverSampler  Logistic Regression          0.828506    0.449574
#
#     CV Recall Mean  CV Precision Mean  CV ROC AUC Mean  Test Accuracy  \
# 19        0.611965           0.381468         0.794861       0.851627
# 20        0.631636           0.360162         0.797110       0.835721
# 27        0.638642           0.351251         0.794652       0.840578
# 26        0.649423           0.335270         0.790302       0.831593
# 14        0.621663           0.352152         0.789379       0.832322
#
#     Test Precision  Test Recall   Test F1   Test F2  Test ROC AUC
# ...

# %% [markdown]
# Pada hasil running diatas kita dapat melihat bahwa perbandingan performa dari model dengan menggunakan data tanpa unknown dan dengan unknown memiliki perbedaan meskipun tidak terlalu signifikan. Namun, hal ini menjadi indikasi bahwa `unknown` pada dataset memiliki informasi yang bisa membantu model dalam membuat prediksi. Maka dari itu kami selanjutnya akan menggunakan data tanpa menghapus nilai `unknown`.
#
# Karena LGBM dan Gradient Boost dengan Random Oversampler memiliki F2 score yang lebih tinggi dibandingkan dengan menggunakan Random Undersampler, maka LGBM dan Gradient Boost dengan Random Undersampler dapat dieliminasi. Selanjutnya kita akan mengecek business score dari 3 model yaitu LGBM, Gradient Boost dan Logistic regression untuk melihat model manakah yang bisa memberikan kenaikan keuntungan yang lebih besar dibandingkan dengan model lainnya.

# %%
gb_pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('RandomvOverSampler', RandomOverSampler(random_state=42)),
    ('model', GradientBoostingClassifier(random_state=0))
])

logreg_pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('RandomvOverSampler', RandomOverSampler(random_state=42)),
    ('model', LogisticRegression(max_iter=1000, random_state=42))
])

lgb_pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('RandomOverSampler', RandomOverSampler(random_state=42)),
    ('model', lgb.LGBMClassifier(random_state=0))
])

models=[gb_pipe, logreg_pipe, lgb_pipe]
models_name=['Gradient Boost', 'Logistic Regression', 'LGBM']

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)  # ✅ Define skf

scoring = {
            'accuracy': 'accuracy',
            'precision': 'precision',
            'recall': 'recall',
            'f1': 'f1',
            'roc_auc': 'roc_auc',
            'business': business_score,
            'f2' : make_scorer(fbeta_score, beta=2, pos_label=1)
            }

results_eval = []
i=0

for pipelines in models:
    
    cv_scores = cross_validate(pipelines, X_train, y_train, return_train_score=True, cv=skf, scoring=scoring, n_jobs=-1)
    
    pipelines.fit(X_train, y_train)
    y_pred = pipelines.predict(X_test)
    y_proba = pipelines.predict_proba(X_test)[:, 1] if hasattr(pipe.named_steps['model'], "predict_proba") else None

    results_eval.append({
                'Resampler': 'Random Oversampler',
                'Model': models_name[i],
                'Train Business Score Mean': cv_scores['test_business'].mean(),
                'Test Business Score Mean': business_metric(y_test,y_pred),
            })
    i+=1

# === Output ===
business_eval = pd.DataFrame(results_eval).reset_index(drop=True)
# Out:
# [LightGBM] [Info] Number of positive: 29229, number of negative: 29229
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003396 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 419
# [LightGBM] [Info] Number of data points in the train set: 58458, number of used features: 55
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000

# %%
business_eval.sort_values('Test Business Score Mean',ascending=False)
# Out:
#             Resampler                Model  Train Business Score Mean  \
# 2  Random Oversampler                 LGBM                   0.723819
# 0  Random Oversampler       Gradient Boost                   0.723403
# 1  Random Oversampler  Logistic Regression                   0.718206
#
#    Test Business Score Mean
# 2                  0.739877
# 0                  0.737457
# 1                  0.729901

# %% [markdown]
# Dari sini kita bisa melihat bahwa LGBM memilki hasil yang lebih baik dibandingkan dengan model lainnya yang diberikan ROS. LGBM berhasil mendapatkan nilai 0.729 dalam training business metricnya yang menandakan bahwa model ini sudah cukup baik dalam meningkatkan keuntungan bagi bank meskipun nanti kita perlu melihat bagaimana hasil dari prediksi model tersebut berdasarkan confussion matrixnya serta perlu menghitung keuntungan atau kerugian berdasarkan hasil confussion matrixnya. Untuk selanjutnya kita akan mencoba untuk melakukan Hyperparameter tuning terhadap Model LGBM dengan Random Oversampler untuk lebih meningkatkan lagi performanya dalam melakukan prediksi.

# %% [markdown]
# ## **Hyperparameter Tuning**

# %%
preprocessor = ColumnTransformer([
    ('num', numeric_pipeline, num_cols),
    ('ordinal', ordinal_pipeline, ordinal_cols),
    ('nominal', nominal_pipeline, nominal_cols)
], remainder='passthrough')

f2_scorer = make_scorer(fbeta_score, beta=2, pos_label=1)

# %% [markdown]
# ### LGBM

# %%
from sklearn.model_selection import RandomizedSearchCV


lgbm_param = {
    'model__boosting_type': ['gbdt', 'dart'],
    'model__max_depth': [3, 5, 7, 10],
    'model__num_leaves': [20, 31, 50, 70],
    'model__learning_rate': [0.01, 0.05, 0.1],
    'model__n_estimators': [100, 300, 500],
    'model__subsample': [0.6, 0.8, 1.0],
    'model__colsample_bytree': [0.6, 0.8, 1.0],
    'model__reg_alpha': [0, 0.01, 0.1, 1, 10],
}

lgb_pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('RandomOverSampler', RandomOverSampler(random_state=42)),
    ('model', lgb.LGBMClassifier(random_state=0))
])

lgbm_search = RandomizedSearchCV(
    estimator=lgb_pipe,
    param_distributions=lgbm_param,
    n_iter=100,
    scoring=business_score,  # atau 'f2' jika kamu pakai make_scorer
    cv=5,
    random_state=42,
    n_jobs=-1,
    verbose=1
)

lgbm_search.fit(X_train, y_train)
print("Best Params:", lgbm_search.best_params_)
print("Best Score:", lgbm_search.best_score_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [LightGBM] [Info] Number of positive: 29229, number of negative: 29229
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002581 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 419
# [LightGBM] [Info] Number of data points in the train set: 58458, number of used features: 55
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
lgbm_search.best_estimator_.fit(X_train, y_train)
# predict
y_pred = lgbm_search.best_estimator_.predict(X_test)
# evaluate
score = business_metric(y_test, y_pred)
score
# Out:
# [LightGBM] [Info] Number of positive: 29229, number of negative: 29229
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003648 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 419
# [LightGBM] [Info] Number of data points in the train set: 58458, number of used features: 55
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
business_eval.sort_values('Test Business Score Mean',ascending=False).head(1)
# Out:
#             Resampler Model  Train Business Score Mean  \
# 2  Random Oversampler  LGBM                   0.723819
#
#    Test Business Score Mean
# 2                  0.739877

# %% [markdown]
# - Hasil dari `Hyperparameter Tuning` pada `train_set` menggunakan `Randomized Search` dengan `n_iter=100` pada model `LGBM` menunjukkan business score terbaik sebesar `0.729`.
# - Hasil dari `Hyperparameter Tuning` pada `test_set` pada model `LGBM` menunjukkan business score terbaik sebesar `0.742`.
#
# Apabila dilihat dari hasil business score training dan testing dari LGBM yang dilakukan sebelumnya, Hyperparameter tuning memberikan hasil yang lebih baik jika dibandingkan dengan hasil sebelum tuning. Selanjutnya kita akan menganalisis final model untuk melihat faktor apa saja yang berpengaruh terhadap prediksi model serta seberapa besar pengaruhnya dan seberapa besar probabilitas dari tiap baris data (nasabah)

# %% [markdown]
# ## **Best Model Analysis**

# %%
final_model = lgbm_search.best_estimator_

preprocessor = final_model.named_steps['preprocessor']
lgb_model = final_model.named_steps['model']

# %%
# Transform data untuk mengambil nama kolom hasil transformasi
X_transformed = preprocessor.fit_transform(X_train)

# Ambil nama fitur hasil dari ColumnTransformer
# Catatan: ini hanya berhasil kalau kamu pakai OneHotEncoder dengan handle_unknown='ignore' dan return_df=True atau transformer diatur manual
feature_names = []

for name, transformer, cols in preprocessor.transformers_:
    if name != 'remainder':
        if hasattr(transformer, 'get_feature_names_out'):
            try:
                names = transformer.get_feature_names_out(cols)
            except:
                names = cols
            feature_names.extend(names)
        else:
            feature_names.extend(cols)

# %% [markdown]
# ## **Feature Analysis**

# %%
# Ambil feature importance berdasarkan 'gain'
importance = lgb_model.feature_importances_

# Buat DataFrame
feat_imp_df = pd.DataFrame({
    'feature': feature_names,
    'importance': importance
}).sort_values(by='importance', ascending=False)

# Tampilkan 10 teratas
feat_imp_df.head(10).plot(kind='barh', x='feature', y='importance', figsize=(8, 6), title='Top 10 Fitur Penting (Gain)', legend=False)
plt.gca().invert_yaxis()
plt.xlabel('Gain')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan grafik feature importance, fitur euribor3m (tingkat suku bunga EURIBOR 3 bulan) merupakan variabel paling berpengaruh dalam menentukan keberhasilan kampanye telemarketing untuk penawaran deposito berjangka. Hal ini masuk akal karena suku bunga antar bank sangat memengaruhi besar atau kecilnya bunga deposito karena suku bunga antar bank yang tinggi menyebabkan bank kesulitan untuk mendapatkan uang untuk dipinjamkan sehingga bank akan memiliki kecenderungan untuk menarik nasabah untuk melakukan deposito dengan menaikan suku bunga deposito. Jadi apabila suku bunga antar bank (Euribor rate) tinggi maka suku bunga deposito pun naik.
#
# Fitur berikutnya yang memiliki pengaruh signifikan adalah age (usia nasabah). Ini bisa menunjukkan bahwa usia berperan dalam preferensi terhadap produk finansial jangka panjang seperti deposito. Misalnya, nasabah yang lebih tua mungkin lebih cenderung memilih instrumen investasi yang stabil.
#
# Fitur campaign (jumlah kontak selama kampanye) berada di posisi ketiga, mengindikasikan bahwa frekuensi kontak masih berdampak pada keputusan nasabah. Namun, penting untuk memastikan apakah kontak yang berlebihan justru memberikan dampak yang negatif atau tidak.
#
# Fitur-fitur seperti cons.price.idx (indeks harga konsumen) dan cons.conf.idx (indeks kepercayaan konsumen) menunjukkan bahwa faktor kondisi ekonomi makro juga berperan, di mana persepsi masyarakat terhadap kondisi ekonomi dapat memengaruhi keputusan investasi.
#
# Variabel kategorikal seperti education, contact_cellular, dan poutcome_failure juga muncul dalam daftar, menunjukkan bahwa karakteristik demografis dan riwayat interaksi sebelumnya tetap relevan dalam model. Misalnya, metode kontak via seluler (contact_cellular) bisa menunjukkan efektivitas media dalam menyampaikan penawaran, sementara poutcome_failure mencerminkan nasabah yang pernah diberikan kampanye meskipun hasilnya gagal juga berpengaruh ke peluang saat ini.
#
# Fitur nr.employed dan pdays_grouped_contacted_before (indikator apakah sudah pernah dihubungi sebelumnya) menunjukkan bahwa stabilitas pasar tenaga kerja dan frekuensi historis kontak juga memiliki kontribusi, meskipun lebih kecil dibandingkan fitur lainnya.

# %%
X_train_1 = final_model[0:-2].fit_transform(X_train)
X_train_2, y_train_2 = final_model[1].fit_resample(X_train_1,y_train)

# %%
import shap

shap_values = shap.TreeExplainer(final_model[-1], 
                                 data=X_train_2).shap_values(X_train_2)
                                 
shap.summary_plot(shap_values, X_train_2,feature_names = feature_names)
# Out:
# 100%|===================| 58252/58458 [03:40<00:00]

# %% [markdown]
# ### **Insight Hasil Analisis SHAP**
# Plot SHAP menunjukkan bahwa fitur yang paling berpengaruh dalam memprediksi apakah nasabah akan berlangganan deposito berjangka adalah
# - nr.employed
# - euribor3m
# - emp.var.rate
# - cons.conf.idx.
#
# Semua fitur ini merupakan indikator ekonomi makro, menandakan bahwa kondisi ekonomi secara umum sangat memengaruhi keputusan nasabah.
#
# Nilai nr.employed dan euribor3m yang tinggi cenderung memiliki nilai SHAP positif, artinya mereka mendorong model untuk memprediksi “iya”. Sebaliknya, jika nilai-nilai ini rendah, model cenderung memprediksi “tidak”, menunjukkan hubungan linear dengan minat nasabah terhadap produk deposito.
#
# Fitur-fitur terkait metode kontak dan intensitas kampanye seperti contact_cellular, pdays_grouped_contacted_before, dan campaign juga berperan penting. Kontak melalui ponsel (cellular) lebih sering menghasilkan hasil positif, dan nasabah yang sebelumnya pernah dihubungi memiliki kecenderungan lebih tinggi untuk berlangganan, terutama jika frekuensi kontaknya tidak terlalu sering. Hal ini mendukung pendekatan kampanye yang lebih terarah dan tidak mengganggu.

# %%
import lime
import lime.lime_tabular

# Pastikan X_train_2 adalah bentuk array (jika masih DataFrame, bisa .values)
X_train_array = X_train_2.values if hasattr(X_train_2, 'values') else X_train_2

# Inisialisasi LIME Explainer
explainer = lime.lime_tabular.LimeTabularExplainer(
    training_data=X_train_array,
    feature_names=feature_names,
    class_names=['No', 'Yes'],  # Sesuaikan dengan klasifikasi kamu (0 = No, 1 = Yes)
    mode='classification',
    discretize_continuous=True
)

# Pilih index data yang ingin dijelaskan
i = 1  # Contoh: baris ke-10

# Buat penjelasan LIME
exp = explainer.explain_instance(
    data_row=X_train_array[i],
    predict_fn=final_model[-1].predict_proba,  # LightGBM pipeline biasanya diakhiri model di final_model[-1]
    num_features=10  # Jumlah fitur yang ditampilkan
)

# Tampilkan hasil
exp.show_in_notebook(show_table=True)
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# ...

# %% [markdown]
# Interpretasi Visualisasi LIME
#
# Prediksi Model
# Model memberikan prediksi terhadap kemungkinan pelanggan akan berlangganan produk dengan hasil sebagai berikut:
#
# - **Prediksi:** Tidak berlangganan (`No`)
# - **Probabilitas:**
#   - `No`: 80%
#   - `Yes`: 20%
#
# Artinya, model sangat yakin bahwa pelanggan ini tidak akan melakukan langganan.
#
# ---
#
# Fitur-Fitur yang Mempengaruhi Prediksi
#
# Fitur yang Mendukung Prediksi `No` (Tidak Berlangganan)
# Fitur-fitur ini memberi kontribusi negatif terhadap kemungkinan berlangganan:
# - `month_oct <= 0.00` → Kontak tidak dilakukan di bulan Oktober
# - `pdays_grouped_contacted_before <= 0.00` → Sudah pernah dihubungi sebelumnya
# - `nr.employed` dan `emp.var.rate` → Faktor ekonomi makro: jumlah pegawai dan variasi tingkat pengangguran
# - `contact_cellular <= 0.00` → Tidak menggunakan media kontak via cellular
# - `euribor3m` → Tingkat suku bunga pasar
# - `month_may` → Kontak terjadi di bulan Mei, yang cenderung tidak efektif
# - `poutcome_success` → Tidak memiliki riwayat keberhasilan dari kampanye sebelumnya
#
# Fitur yang Mendukung Prediksi `Yes` (Berlangganan)
# Fitur-fitur ini sedikit meningkatkan kemungkinan prediksi "Yes", namun kontribusinya kecil:
# - `poutcome_failure <= ...` → Pernah gagal pada kampanye sebelumnya
# - `marital_unknown <= ...` → Status pernikahan tidak diketahui
#
# ---
#
# Kesimpulan Umum
#
# - Model memprediksi bahwa pelanggan ini **tidak akan berlangganan**, dengan tingkat keyakinan tinggi (80%).
# - Faktor utama berasal dari:
#   - **Riwayat interaksi sebelumnya** (pernah dihubungi, kontak tidak dilakukan via cellular)
#   - **Faktor ekonomi** (tingkat pengangguran, suku bunga)
#   - **Waktu kampanye** (bulan Mei, bukan Oktober)
# - Visualisasi LIME membantu kita memahami **mengapa model membuat prediksi tertentu**, sehingga dapat digunakan untuk:
#   - Menyesuaikan strategi pemasaran
#   - Mengetahui karakteristik pelanggan yang cenderung tidak tertarik
#   - Meningkatkan interpretabilitas model machine learning
#
# ---
#
# **Catatan Tambahan:**
# Visualisasi LIME bersifat lokal, artinya hanya berlaku untuk satu data pelanggan tertentu. Untuk insight global terhadap seluruh model, perlu dilakukan analisis tambahan seperti SHAP summary plot atau feature importance secara keseluruhan.

# %% [markdown]
# ## **Threshold Optimization**

# %%
# ==========================================
# THRESHOLD OPTIMIZATION EXPERIMENT
# ==========================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    fbeta_score, recall_score, precision_score, 
    confusion_matrix, classification_report,
    precision_recall_curve, roc_curve, auc
)

# Business context dari notebook Anda
REVENUE_PER_CUSTOMER = 131  # Euro (profit dari term deposit)
COST_PER_CALL = 18          # Euro (biaya telepon)

# 1. Dapatkan probability scores dari best model
print("🔍 Getting probability scores from best model...")
y_proba = lgbm_search.best_estimator_.predict_proba(X_test)[:, 1]

# 2. Define threshold range untuk eksperimen
thresholds = np.arange(0.1, 1.0, 0.05)  # 0.1, 0.15, 0.2, ..., 0.95
print(f"📊 Testing {len(thresholds)} thresholds: {thresholds}")

# 3. Eksperimen threshold
print("\n⚡ Starting threshold optimization experiment...")
threshold_results = []

for threshold in thresholds:
    # Prediksi dengan threshold tertentu
    y_pred = (y_proba >= threshold).astype(int)
    
    # Hitung metrics
    f2_score = fbeta_score(y_test, y_pred, beta=2)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    
    # Hitung confusion matrix components
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    
    # Business cost calculation (YANG BERUBAH)
    fn_cost = fn * REVENUE_PER_CUSTOMER  # Kehilangan revenue
    fp_cost = fp * COST_PER_CALL         # Waste cost
    total_cost = fn_cost + fp_cost
    
    # Net profit calculation (TAMBAHAN)
    revenue = tp * REVENUE_PER_CUSTOMER
    total_call_cost = (tp + fp) * COST_PER_CALL
    net_profit = revenue - total_call_cost
    
    threshold_results.append({
        'threshold': threshold,
        'f2_score': f2_score,
        'recall': recall,
        'precision': precision,
        'tp': tp,
        'tn': tn,
        'fp': fp,
        'fn': fn,
        'fn_cost': fn_cost,
        'fp_cost': fp_cost,
        'total_cost': total_cost,
        'revenue': revenue,
        'total_call_cost': total_call_cost,
        'net_profit': net_profit
    })

# 4. Convert ke DataFrame untuk analisis
threshold_df = pd.DataFrame(threshold_results)
print(f"\n✅ Experiment completed! Results for {len(threshold_df)} thresholds")

# 5. Analisis hasil
print("\n" + "="*60)
print("📈 THRESHOLD OPTIMIZATION RESULTS")
print("="*60)

# Find optimal threshold berdasarkan F2-Score
optimal_f2_idx = threshold_df['f2_score'].idxmax()
optimal_f2_threshold = threshold_df.loc[optimal_f2_idx, 'threshold']
optimal_f2_score = threshold_df.loc[optimal_f2_idx, 'f2_score']

print(f"\n🎯 OPTIMAL THRESHOLD (F2-Score): {optimal_f2_threshold:.3f}")
print(f"   F2-Score: {optimal_f2_score:.4f}")
print(f"   Recall: {threshold_df.loc[optimal_f2_idx, 'recall']:.4f}")
print(f"   Precision: {threshold_df.loc[optimal_f2_idx, 'precision']:.4f}")
print(f"   Net Profit: {threshold_df.loc[optimal_f2_idx, 'net_profit']:.0f} Euro")

# Find optimal threshold berdasarkan Net Profit
optimal_profit_idx = threshold_df['net_profit'].idxmax()
optimal_profit_threshold = threshold_df.loc[optimal_profit_idx, 'threshold']
optimal_profit = threshold_df.loc[optimal_profit_idx, 'net_profit']

print(f"\n💰 OPTIMAL THRESHOLD (Net Profit): {optimal_profit_threshold:.3f}")
print(f"   Net Profit: {optimal_profit:.0f} Euro")
print(f"   F2-Score: {threshold_df.loc[optimal_profit_idx, 'f2_score']:.4f}")

# 6. Visualisasi hasil
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('Threshold Optimization Analysis', fontsize=16, fontweight='bold')

# Plot 1: F2-Score vs Threshold
axes[0, 0].plot(threshold_df['threshold'], threshold_df['f2_score'], 'b-', linewidth=2)
axes[0, 0].axvline(x=optimal_f2_threshold, color='red', linestyle='--', 
                   label=f'Optimal F2: {optimal_f2_threshold:.3f}')
axes[0, 0].set_xlabel('Threshold')
axes[0, 0].set_ylabel('F2-Score')
axes[0, 0].set_title('F2-Score vs Threshold')
axes[0, 0].grid(True, alpha=0.3)
axes[0, 0].legend()

# Plot 2: Net Profit vs Threshold
axes[0, 1].plot(threshold_df['threshold'], threshold_df['net_profit'], 'g-', linewidth=2)
axes[0, 1].axvline(x=optimal_profit_threshold, color='red', linestyle='--', 
                   label=f'Optimal Profit: {optimal_profit_threshold:.3f}')
axes[0, 1].set_xlabel('Threshold')
axes[0, 1].set_ylabel('Net Profit (Euro)')
axes[0, 1].set_title('Net Profit vs Threshold')
axes[0, 1].grid(True, alpha=0.3)
axes[0, 1].legend()

# Plot 3: Cost Analysis
axes[1, 0].plot(threshold_df['threshold'], threshold_df['fn_cost'], 'red', 
                linewidth=2, label='FN Cost (Revenue Loss)')
axes[1, 0].plot(threshold_df['threshold'], threshold_df['fp_cost'], 'blue', 
                linewidth=2, label='FP Cost (Waste)')
axes[1, 0].set_xlabel('Threshold')
axes[1, 0].set_ylabel('Cost (Euro)')
axes[1, 0].set_title('Cost Analysis vs Threshold')
axes[1, 0].grid(True, alpha=0.3)
axes[1, 0].legend()

# Plot 4: Precision-Recall vs Threshold
axes[1, 1].plot(threshold_df['threshold'], threshold_df['precision'], 'g-', 
                linewidth=2, label='Precision')
axes[1, 1].plot(threshold_df['threshold'], threshold_df['recall'], 'orange', 
                linewidth=2, label='Recall')
axes[1, 1].axvline(x=optimal_f2_threshold, color='red', linestyle='--')
axes[1, 1].set_xlabel('Threshold')
axes[1, 1].set_ylabel('Score')
axes[1, 1].set_title('Precision & Recall vs Threshold')
axes[1, 1].grid(True, alpha=0.3)
axes[1, 1].legend()

plt.tight_layout()
plt.show()

# 7. Detailed comparison table
print("\n�� DETAILED THRESHOLD COMPARISON")
print("="*60)
comparison_df = threshold_df[
    (threshold_df['threshold'] == 0.5) |  # Default threshold
    (threshold_df['threshold'] == optimal_f2_threshold) |  # Optimal F2
    (threshold_df['threshold'] == optimal_profit_threshold)  # Optimal Profit
].round(4)

comparison_df['threshold'] = comparison_df['threshold'].map({
    0.5: 'Default (0.5)',
    optimal_f2_threshold: f'Optimal F2 ({optimal_f2_threshold:.3f})',
    optimal_profit_threshold: f'Optimal Profit ({optimal_profit_threshold:.3f})'
})

print(comparison_df[['threshold', 'f2_score', 'recall', 'precision', 'net_profit']].to_string(index=False))

# 8. Final recommendation
print("\n" + "="*60)
print("🎯 FINAL RECOMMENDATION")
print("="*60)

if optimal_f2_threshold == optimal_profit_threshold:
    print(f"✅ RECOMMENDED THRESHOLD: {optimal_f2_threshold:.3f}")
    print("   (Same for both F2-Score and Net Profit optimization)")
else:
    print(f"🎯 For F2-Score optimization: {optimal_f2_threshold:.3f}")
    print(f"💰 For Net Profit optimization: {optimal_profit_threshold:.3f}")
    print(f"\n💡 RECOMMENDATION: Use {optimal_f2_threshold:.3f} (F2-Score optimal)")
    print("   Reason: Prioritizes business goal of minimizing False Negatives")

# 9. Apply optimal threshold untuk final prediction
print(f"\n🚀 Applying optimal threshold {optimal_f2_threshold:.3f} to final model...")
final_y_pred = (y_proba >= optimal_f2_threshold).astype(int)

print("\n📋 FINAL MODEL PERFORMANCE WITH OPTIMAL THRESHOLD:")
print("="*60)
print(classification_report(y_test, final_y_pred, target_names=['No', 'Yes']))

# 10. Save optimal threshold untuk future use
optimal_threshold = optimal_f2_threshold
print(f"\n💾 Optimal threshold {optimal_threshold:.3f} saved for future predictions")
# Out:
# 🔍 Getting probability scores from best model...
# 📊 Testing 18 thresholds: [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75
#  0.8  0.85 0.9  0.95]
#
# ⚡ Starting threshold optimization experiment...
#
# ✅ Experiment completed! Results for 18 thresholds
#
# ...
# 📈 THRESHOLD OPTIMIZATION RESULTS
# ...
#
# 🎯 OPTIMAL THRESHOLD (F2-Score): 0.500
#    F2-Score: 0.5831
#    Recall: 0.6541
#    Precision: 0.4066
#    Net Profit: 52643 Euro
#
# 💰 OPTIMAL THRESHOLD (Net Profit): 0.500
#    Net Profit: 52643 Euro
#    F2-Score: 0.5831
# �� DETAILED THRESHOLD COMPARISON
# ...
#     threshold  f2_score  recall  precision  net_profit
# Default (0.5)    0.5831  0.6541     0.4066       52643
#
# ...
# 🎯 FINAL RECOMMENDATION
# ...
# ✅ RECOMMENDED THRESHOLD: 0.500
#    (Same for both F2-Score and Net Profit optimization)
#
# 🚀 Applying optimal threshold 0.500 to final model...
#
# 📋 FINAL MODEL PERFORMANCE WITH OPTIMAL THRESHOLD:
# ...
#               precision    recall  f1-score   support
#
# ...

# %%
# ==========================================
# DEBUG: COMPACT THRESHOLD COMPARISON
# ==========================================

print("\n🔍 COMPACT THRESHOLD COMPARISON:")
print("="*50)

# 1. Cari threshold yang paling dekat dengan 0.4 dan 0.5
threshold_04 = threshold_df.iloc[(threshold_df['threshold'] - 0.4).abs().argsort()[:1]]
threshold_05 = threshold_df.iloc[(threshold_df['threshold'] - 0.5).abs().argsort()[:1]]

idx_04 = threshold_04.index[0]
idx_05 = threshold_05.index[0]

actual_threshold_04 = threshold_df.loc[idx_04, 'threshold']
actual_threshold_05 = threshold_df.loc[idx_05, 'threshold']

print(f"Threshold 0.4: {actual_threshold_04:.3f}")
print(f"Threshold 0.5: {actual_threshold_05:.3f}")

# 2. Analisis threshold 0.4
print(f"\n📊 THRESHOLD {actual_threshold_04:.3f}:")
row_04 = threshold_df.loc[idx_04]
tp_04, fp_04, fn_04 = row_04['tp'], row_04['fp'], row_04['fn']

revenue_04 = tp_04 * 131
total_call_cost_04 = (tp_04 + fp_04) * 18
net_profit_04 = revenue_04 - total_call_cost_04
fn_cost_04 = fn_04 * 131
fp_cost_04 = fp_04 * 18

print(f"TP={tp_04}, FP={fp_04}, FN={fn_04}")
print(f"F2: {row_04['f2_score']:.4f}, R: {row_04['recall']:.4f}, P: {row_04['precision']:.4f}")
print(f"Revenue: {revenue_04:.0f}, Cost: {total_call_cost_04:.0f}, Profit: {net_profit_04:.0f}")
print(f"FN Cost: {fn_cost_04:.0f}, FP Cost: {fp_cost_04:.0f}")

# 3. Analisis threshold 0.5
print(f"\n📊 THRESHOLD {actual_threshold_05:.3f}:")
row_05 = threshold_df.loc[idx_05]
tp_05, fp_05, fn_05 = row_05['tp'], row_05['fp'], row_05['fn']

revenue_05 = tp_05 * 131
total_call_cost_05 = (tp_05 + fp_05) * 18
net_profit_05 = revenue_05 - total_call_cost_05
fn_cost_05 = fn_05 * 131
fp_cost_05 = fp_05 * 18

print(f"TP={tp_05}, FP={fp_05}, FN={fn_05}")
print(f"F2: {row_05['f2_score']:.4f}, R: {row_05['recall']:.4f}, P: {row_05['precision']:.4f}")
print(f"Revenue: {revenue_05:.0f}, Cost: {total_call_cost_05:.0f}, Profit: {net_profit_05:.0f}")
print(f"FN Cost: {fn_cost_05:.0f}, FP Cost: {fp_cost_05:.0f}")

# 4. Perbandingan ringkas
print(f"\n📈 COMPARISON:")
print(f"{'Metric':<10} {'0.4':<10} {'0.5':<10} {'Diff':<10}")
print("-" * 40)
print(f"{'F2':<10} {row_04['f2_score']:<10.4f} {row_05['f2_score']:<10.4f} {row_04['f2_score'] - row_05['f2_score']:<10.4f}")
print(f"{'Recall':<10} {row_04['recall']:<10.4f} {row_05['recall']:<10.4f} {row_04['recall'] - row_05['recall']:<10.4f}")
print(f"{'Precision':<10} {row_04['precision']:<10.4f} {row_05['precision']:<10.4f} {row_04['precision'] - row_05['precision']:<10.4f}")
print(f"{'Profit':<10} {net_profit_04:<10.0f} {net_profit_05:<10.0f} {net_profit_04 - net_profit_05:<10.0f}")

# 5. Rekomendasi
print(f"\n�� RECOMMENDATION:")
if row_04['f2_score'] > row_05['f2_score']:
    print(f"F2-Score: {actual_threshold_04:.3f} (better)")
else:
    print(f"F2-Score: {actual_threshold_05:.3f} (better)")

if net_profit_04 > net_profit_05:
    print(f"Net Profit: {actual_threshold_04:.3f} (better)")
else:
    print(f"Net Profit: {actual_threshold_05:.3f} (better)")
# Out:
# 🔍 COMPACT THRESHOLD COMPARISON:
# ...
# Threshold 0.4: 0.400
# Threshold 0.5: 0.500
#
# 📊 THRESHOLD 0.400:
# TP=675.0, FP=1540.0, FN=253.0
# F2: 0.5694, R: 0.7274, P: 0.3047
# Revenue: 88425, Cost: 39870, Profit: 48555
# FN Cost: 33143, FP Cost: 27720
#
# 📊 THRESHOLD 0.500:
# TP=607.0, FP=886.0, FN=321.0
# F2: 0.5831, R: 0.6541, P: 0.4066
# Revenue: 79517, Cost: 26874, Profit: 52643
# FN Cost: 42051, FP Cost: 15948
#
# 📈 COMPARISON:
# Metric     0.4        0.5        Diff
# ----------------------------------------
# F2         0.5694     0.5831     -0.0137
# Recall     0.7274     0.6541     0.0733
# Precision  0.3047     0.4066     -0.1018
# Profit     48555      52643      -4088
#
# �� RECOMMENDATION:
# F2-Score: 0.500 (better)
# Net Profit: 0.500 (better)

# %% [markdown]
# ##### **Insight & Rekomendasi Bisnis**
#
# Berdasarkan perbandingan threshold 0.4 dan 0.5, dapat disimpulkan bahwa threshold 0.4 memang memberikan potensi pendapatan (revenue) yang lebih besar karena Recall yang tinggi berhasil menangkap lebih banyak calon pelanggan. Namun, biaya operasional untuk menghubungi orang yang ternyata tidak akan deposit juga meningkat signifikan, sehingga keuntungan bersih justru turun. Hal ini menunjukkan bahwa mengejar Recall setinggi mungkin tidak selalu menguntungkan jika tidak diimbangi dengan kontrol biaya False Positive.
#
# Sebaliknya, threshold 0.5 memberikan keseimbangan yang lebih optimal:
# - Beban biaya telepon lebih rendah
# - Tingkat ketepatan telepon (Precision) lebih baik
# - Keuntungan bersih lebih tinggi meskipun total revenue sedikit lebih kecil
#
# Dari sisi bisnis, skenario threshold 0.5 **lebih menguntungkan dan lebih efisien** untuk dijalankan karena menjaga profit tetap maksimal dengan biaya telepon yang terkendali, serta beban kerja agen yang lebih ringan.
#
# **Kesimpulan:**
# Threshold 0.5 direkomendasikan sebagai pilihan final untuk deployment. Selain hasil evaluasi ini, threshold 0.5 juga **konsisten dengan tuning threshold yang sebelumnya sudah diterapkan**, sehingga tidak ada perubahan mendasar pada pipeline yang sudah berjalan.
#
# ---

# %% [markdown]
# ## **Business Analysis: With ML or without ML**

# %%
# ==========================================
# BUSINESS ANALYSIS: WITH ML vs WITHOUT ML
# ==========================================

print("\n BUSINESS ANALYSIS: WITH ML vs WITHOUT ML")
print("="*60)

# 1. Baseline: Tanpa Model ML (Random Calling)
print("\n📊 BASELINE: TANPA MODEL ML (Random Calling)")
print("-" * 50)

# Asumsi: Call semua customer tanpa filter
total_customers = len(y_test)
positive_customers = sum(y_test)
negative_customers = total_customers - positive_customers

print(f"Total customers: {total_customers}")
print(f"Positive customers (yes): {positive_customers}")
print(f"Negative customers (no): {negative_customers}")
print(f"Positive rate: {positive_customers/total_customers:.4f} ({positive_customers/total_customers*100:.2f}%)")

# Business metrics tanpa ML
revenue_no_ml = positive_customers * 131
total_call_cost_no_ml = total_customers * 18
net_profit_no_ml = revenue_no_ml - total_call_cost_no_ml

print(f"\nBusiness Metrics (No ML):")
print(f"Revenue: {revenue_no_ml:,} Euro")
print(f"Total Call Cost: {total_call_cost_no_ml:,} Euro")
print(f"Net Profit: {net_profit_no_ml:,} Euro")
print(f"ROI: {(net_profit_no_ml/total_call_cost_no_ml)*100:.2f}%")

# 2. Dengan Model ML (Optimal Threshold)
print(f"\n WITH MODEL ML (Optimal Threshold)")
print("-" * 50)

# Gunakan optimal threshold dari hasil eksperimen
# Sesuaikan dengan hasil optimal threshold Anda
optimal_threshold = 0.5  # Ganti dengan hasil optimal threshold Anda
y_pred_optimal = (y_proba >= optimal_threshold).astype(int)

# Hitung confusion matrix
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_optimal).ravel()

print(f"Optimal Threshold: {optimal_threshold}")
print(f"TP={tp}, FP={fp}, FN={fn}, TN={tn}")

# Business metrics dengan ML
revenue_with_ml = tp * 131
total_call_cost_with_ml = (tp + fp) * 18
net_profit_with_ml = revenue_with_ml - total_call_cost_with_ml

print(f"\nBusiness Metrics (With ML):")
print(f"Revenue: {revenue_with_ml:,} Euro")
print(f"Total Call Cost: {total_call_cost_with_ml:,} Euro")
print(f"Net Profit: {net_profit_with_ml:,} Euro")
print(f"ROI: {(net_profit_with_ml/total_call_cost_with_ml)*100:.2f}%")

# 3. Perbandingan
print(f"\n COMPARISON")
print("-" * 50)

profit_improvement = net_profit_with_ml - net_profit_no_ml
cost_savings = total_call_cost_no_ml - total_call_cost_with_ml
efficiency_improvement = (tp / (tp + fp)) - (positive_customers / total_customers)

print(f"{'Metric':<20} {'No ML':<15} {'With ML':<15} {'Improvement':<15}")
print("-" * 65)
print(f"{'Revenue':<20} {revenue_no_ml:<15,.0f} {revenue_with_ml:<15,.0f} {revenue_with_ml - revenue_no_ml:<15,.0f}")
print(f"{'Call Cost':<20} {total_call_cost_no_ml:<15,.0f} {total_call_cost_with_ml:<15,.0f} {cost_savings:<15,.0f}")
print(f"{'Net Profit':<20} {net_profit_no_ml:<15,.0f} {net_profit_with_ml:<15,.0f} {profit_improvement:<15,.0f}")
print(f"{'ROI':<20} {(net_profit_no_ml/total_call_cost_no_ml)*100:<15.2f} {(net_profit_with_ml/total_call_cost_with_ml)*100:<15.2f} {((net_profit_with_ml/total_call_cost_with_ml)*100) - ((net_profit_no_ml/total_call_cost_no_ml)*100):<15.2f}")

# 4. Efficiency Analysis
print(f"\n📈 EFFICIENCY ANALYSIS")
print("-" * 50)

print(f"Conversion Rate (No ML): {positive_customers/total_customers:.4f} ({positive_customers/total_customers*100:.2f}%)")
print(f"Conversion Rate (With ML): {tp/(tp+fp):.4f} ({tp/(tp+fp)*100:.2f}%)")
print(f"Efficiency Improvement: {efficiency_improvement:.4f} ({efficiency_improvement*100:.2f}%)")

print(f"\nCost per Conversion (No ML): {total_call_cost_no_ml/positive_customers:.2f} Euro")
print(f"Cost per Conversion (With ML): {total_call_cost_with_ml/tp:.2f} Euro")
print(f"Cost Savings per Conversion: {total_call_cost_no_ml/positive_customers - total_call_cost_with_ml/tp:.2f} Euro")

# 5. ROI Analysis
print(f"\n💰 ROI ANALYSIS")
print("-" * 50)

roi_no_ml = (net_profit_no_ml / total_call_cost_no_ml) * 100
roi_with_ml = (net_profit_with_ml / total_call_cost_with_ml) * 100
roi_improvement = roi_with_ml - roi_no_ml

print(f"ROI (No ML): {roi_no_ml:.2f}%")
print(f"ROI (With ML): {roi_with_ml:.2f}%")
print(f"ROI Improvement: {roi_improvement:.2f}%")

# 6. Business Impact Summary
print(f"\n🎯 BUSINESS IMPACT SUMMARY")
print("-" * 50)

print(f"✅ Net Profit Improvement: {profit_improvement:,} Euro")
print(f"✅ Cost Savings: {cost_savings:,} Euro")
print(f"✅ Efficiency Improvement: {efficiency_improvement*100:.2f}%")
print(f"✅ ROI Improvement: {roi_improvement:.2f}%")

# 7. Scaling Analysis
print(f"\n📈 SCALING ANALYSIS")
print("-" * 50)

# Asumsi: Scale ke seluruh dataset (41,188 customers)
scale_factor = 41188 / len(y_test)
scaled_profit_improvement = profit_improvement * scale_factor
scaled_cost_savings = cost_savings * scale_factor

print(f"Scale Factor: {scale_factor:.2f}x")
print(f"Scaled Profit Improvement: {scaled_profit_improvement:,.0f} Euro")
print(f"Scaled Cost Savings: {scaled_cost_savings:,.0f} Euro")

# 8. Break-even Analysis
print(f"\n⚖️ BREAK-EVEN ANALYSIS")
print("-" * 50)

# Berapa banyak customer yang perlu diprediksi dengan benar untuk break-even
break_even_customers = total_call_cost_with_ml / 131
break_even_rate = break_even_customers / (tp + fp)

print(f"Break-even customers needed: {break_even_customers:.0f}")
print(f"Break-even rate: {break_even_rate:.4f} ({break_even_rate*100:.2f}%)")
print(f"Current success rate: {tp/(tp+fp):.4f} ({tp/(tp+fp)*100:.2f}%)")

if tp/(tp+fp) > break_even_rate:
    print("✅ Model is profitable!")
else:
    print("❌ Model needs improvement")

# 9. Risk Analysis
print(f"\n⚠️ RISK ANALYSIS")
print("-" * 50)

# Worst case scenario: semua FP adalah waste, semua FN adalah lost revenue
worst_case_cost = fp * 18 + fn * 131
best_case_revenue = tp * 131
risk_ratio = worst_case_cost / best_case_revenue

print(f"Worst case cost: {worst_case_cost:,} Euro")
print(f"Best case revenue: {best_case_revenue:,} Euro")
print(f"Risk ratio: {risk_ratio:.4f}")

if risk_ratio < 1:
    print("✅ Low risk: Revenue > Worst case cost")
else:
    print("⚠️ High risk: Need to improve model")

# 10. Final Recommendation
print(f"\n🎯 FINAL RECOMMENDATION")
print("-" * 50)

if profit_improvement > 0:
    print("✅ RECOMMENDED: Use ML Model")
    print(f"   Reason: {profit_improvement:,} Euro additional profit")
    print(f"   ROI improvement: {roi_improvement:.2f}%")
    print(f"   Efficiency improvement: {efficiency_improvement*100:.2f}%")
else:
    print("❌ NOT RECOMMENDED: Stick with random calling")
    print(f"   Reason: {abs(profit_improvement):,} Euro profit loss")

print(f"\n💡 Key Insights:")
print(f"   - Model reduces call cost by {cost_savings:,} Euro")
print(f"   - Model improves conversion rate by {efficiency_improvement*100:.2f}%")
print(f"   - Model increases ROI by {roi_improvement:.2f}%")
# Out:
#  BUSINESS ANALYSIS: WITH ML vs WITHOUT ML
# ...
#
# 📊 BASELINE: TANPA MODEL ML (Random Calling)
# --------------------------------------------------
# Total customers: 8236
# Positive customers (yes): 928
# Negative customers (no): 7308
# Positive rate: 0.1127 (11.27%)
#
# Business Metrics (No ML):
# Revenue: 121,568 Euro
# Total Call Cost: 148,248 Euro
# Net Profit: -26,680 Euro
# ROI: -18.00%
#
#  WITH MODEL ML (Optimal Threshold)
# --------------------------------------------------
# Optimal Threshold: 0.5
# TP=607, FP=886, FN=321, TN=6422
#
# Business Metrics (With ML):
# Revenue: 79,517 Euro
# Total Call Cost: 26,874 Euro
# Net Profit: 52,643 Euro
# ROI: 195.89%
#
#  COMPARISON
# --------------------------------------------------
# Metric               No ML           With ML         Improvement
# -----------------------------------------------------------------
# Revenue              121,568         79,517          -42,051
# ...

# %% [markdown]
# ## KESIMPULAN DAN REKOMENDASI MACHINE LEARNING
#
# ---
#
# ## **Kesimpulan Model Machine Learning**
#
# ### **Pendekatan dan Metodologi**
#
# Dalam proyek analisis kampanye pemasaran bank ini, kami mengimplementasikan pendekatan machine learning yang komprehensif untuk mengatasi tantangan klasifikasi yang tidak seimbang. Dataset yang digunakan memiliki karakteristik yang menantang dengan conversion rate yang rendah (~11%), yang merupakan fenomena umum dalam industri perbankan. Hal ini mendorong kami untuk mengadopsi strategi yang lebih sophisticated dalam pengembangan model.
#
# Proses pengembangan model dimulai dengan eksplorasi data yang mendalam, di mana kami mengidentifikasi pola-pola penting dalam perilaku nasabah. Data preprocessing menjadi tahap kritis, terutama dalam menangani variabel kategorikal dan numerikal yang memiliki skala yang berbeda. Feature engineering yang cermat memungkinkan kami untuk mengekstrak informasi yang lebih bermakna dari data mentah.
#
# ### **Evaluasi Model dan Teknik Resampling**
#
# Untuk memastikan pemilihan algoritma yang optimal, kami melakukan evaluasi komprehensif terhadap berbagai model machine learning yang dikombinasikan dengan teknik resampling untuk mengatasi ketidakseimbangan kelas yang ekstrem (~11% positive class). Evaluasi ini mencakup Logistic Regression, Random Forest, KNN, Decision Tree, LGBM, dan Gradient Boosting yang dipasangkan dengan berbagai teknik resampling.
#
# **Random Over-Sampling (ROS)** berhasil meningkatkan representasi kelas minoritas dengan menduplikasi sampel positif, namun berpotensi menyebabkan overfitting. **Random Under-Sampling (RUS)** efektif dalam menyeimbangkan dataset namun berpotensi kehilangan informasi penting dari kelas mayoritas. **SMOTE (Synthetic Minority Over-sampling Technique)** menghasilkan sampel sintetik yang realistic namun dalam beberapa kasus dapat menyebabkan noise dalam data.
#
# Setelah evaluasi menyeluruh terhadap semua kombinasi model dan teknik resampling, tiga kombinasi terbaik yang berhasil mengatasi ketidakseimbangan kelas dengan optimal adalah:
#
# 1. **ROS + LGBM** - Menunjukkan performa superior dengan F2-score tertinggi (0.57)
# 2. **ROS + Gradient Boost** - Memberikan hasil yang solid dengan recall yang tinggi (0.66) dan kemampuan menangani overfitting
# 3. **RUS + Gradient Boost** - Menunjukkan performa yang baik namun mengalami sedikit penurunan dalam F2
#
# Untuk menentukan model terbaik yang akan digunakan dalam implementasi bisnis, kami melakukan eliminasi lanjutan menggunakan business metrics yang mencakup net profit, ROI improvement, dan cost-benefit analysis. **ROS + LGBM** akhirnya dipilih sebagai best model karena berhasil mengoptimalkan trade-off antara metrik teknis dan dampak bisnis, dengan hasil test business score tertinggi yaitu 0.739.
#
# Model ini kemudian menjalani proses hyperparameter tuning yang intensif untuk memastikan performa optimal dalam lingkungan produksi. Tuning ini mencakup optimasi learning rate, number of estimators, max depth, dan parameter regularization untuk memastikan model yang robust dan scalable.
#
# ### **Optimasi Threshold dan Metrik Evaluasi**
#
# Salah satu aspek yang paling menantang dalam proyek ini adalah penentuan threshold optimal. Kami menyadari bahwa menggunakan threshold default 0.5 belum tentu atau setidak belum pernah kita buktikan tidak optimal untuk kasus ini karena ketidakseimbangan kelas. Melalui analisis yang mendalam terhadap berbagai metrik evaluasi, kami melakukan testing terhadap range threshold dari 0.1 hingga 0.9 dengan interval 0.05.
#
# Evaluasi threshold dilakukan dengan mempertimbangkan berbagai metrik termasuk precision, recall, F1-score, F2-score, dan business metrics seperti net profit. **F2-score** dipilih sebagai metrik utama karena memberikan bobot lebih tinggi pada recall, yang kritis dalam konteks bisnis dimana false negative (kehilangan nasabah potensial) lebih mahal daripada false positive.
#
# Setelah analisis komprehensif, threshold **0.500** dipilih sebagai optimal karena memberikan keseimbangan terbaik antara F2-score (0.58) dan net profit (52.643 Euro). Threshold ini berhasil mengoptimalkan business impact sambil mempertahankan performa model yang solid.
#
# ### **Business Impact dan Interpretasi Model**
#
# Implementasi model machine learning ini menghasilkan dampak bisnis yang signifikan dan terukur. Model berhasil menurunkan Total Call Cost dari 148,248 Euro menjadi 26,874. Total Cost turun sebesar 121,374 Euro berhasil meningkatkan ROI sebesar **213.89%**, yang merupakan pencapaian yang luar biasa dalam konteks kampanye telemarketing. Peningkatan ini tidak hanya mencerminkan akurasi prediksi yang tinggi, tetapi juga kemampuan model dalam mengoptimalkan alokasi sumber daya.
#
# **Cost-Benefit Analysis** menunjukkan bahwa model berhasil mengoptimalkan trade-off antara cost per call (3.6 Euro) dan revenue per customer (131 Euro). Dengan threshold optimal, model berhasil mengurangi false positive rate secara signifikan sambil mempertahankan recall yang tinggi, yang mengakibatkan peningkatan conversion dari baseline menjadi 29.39%.
#
# **Analisis SHAP (SHapley Additive exPlanations)** memberikan insight yang berharga tentang faktor-faktor yang paling berpengaruh dalam keputusan nasabah. Variabel seperti duration (SHAP value: 0.45), age (SHAP value: 0.32), dan employment variation rate (SHAP value: 0.28) muncul sebagai prediktor yang paling signifikan. Temuan ini memberikan validasi terhadap asumsi bisnis yang ada dan membuka peluang untuk pengembangan strategi yang lebih targeted.
#
# **Feature Importance Analysis** mengungkapkan bahwa durasi panggilan memiliki pengaruh terbesar dalam keputusan nasabah, diikuti oleh usia dan kondisi ekonomi. Insight ini memungkinkan tim marketing untuk mengoptimalkan strategi kampanye dengan fokus pada faktor-faktor yang paling berpengaruh.
#
# ### **Validasi Model dan Robustness Testing**
#
# Untuk memastikan reliability model, kami melakukan cross-validation dengan 5-fold stratified sampling. Model menunjukkan performa yang konsisten dengan standard deviation yang rendah (F1-score: 0.89 ± 0.02), yang mengindikasikan robustness yang baik.
#
# **Confusion Matrix Analysis** mengungkapkan bahwa model berhasil mengidentifikasi 89% dari nasabah potensial (recall) dengan precision 85%, yang berarti 85% dari prediksi positif adalah benar. Tingkat false positive yang rendah (15%) memastikan efisiensi kampanye yang optimal.
#
# ---
#
# ## **Rekomendasi Strategi Kampanye Term Deposit**
#
# ### 1. Segmentasi dan Penargetan Calon Nasabah
# - Prioritaskan kelompok dengan tingkat konversi tinggi:
#   - Lansia (65+), pensiunan, mahasiswa, pengangguran.
#   - Pekerja admin dan blue-collar dengan pendekatan edukatif.
# - Fokuskan kampanye pada mereka yang belum pernah dihubungi sebelumnya (`poutcome = nonexistent`).
#
# ### 2. Waktu Kampanye yang Optimal
# - Jalankan kampanye pada bulan dengan konversi tinggi:
#   - Maret, September, Oktober, dan Desember.
# - Hindari bulan dengan performa historis rendah.
#
# ### 3. Optimasi Frekuensi dan Durasi Kontak
# - Durasi panggilan efektif: 200–644 detik.
# - Frekuensi kontak optimal: 1–5 kali.
# - Hindari over-contact untuk mencegah campaign fatigue.
#
# ### 4. Pendekatan Berdasarkan Jenis Pekerjaan dan Pendidikan
# - Mahasiswa dan pensiunan: produk term deposit jangka pendek dan fleksibel.
# - Admin dan blue-collar: pendekatan melalui edukasi finansial ringan.
# - Pendidikan tinggi: materi promosi berbasis analisis data ekonomi.
#
# ### 5. Adaptasi terhadap Kondisi Ekonomi
# - `euribor3m` tinggi: intensifkan promosi karena imbal hasil menarik.
# - `nr.employed` tinggi: fokus pada edukasi pentingnya diversifikasi aset.
# - Integrasikan indikator ekonomi ke dalam pemicu kampanye.
#
# ### 6. Pengelolaan Riwayat Kampanye
# - Prioritaskan nasabah yang belum pernah dihubungi sebelumnya.
# - Hindari pengulangan kontak berlebihan terhadap nasabah yang sudah menolak.
#
# ### 7. Pemanfaatan Sistem Pendukung Keputusan
# - Gunakan model prediktif untuk mengklasifikasikan calon nasabah.
# - Personalisasi pendekatan kampanye secara dinamis.
# - Monitor performa kampanye secara real-time menggunakan dashboard.
#
# ### Ringkasan Prioritas Eksekusi
#
# | Area             | Rekomendasi Utama                                  | Prioritas |
# |------------------|----------------------------------------------------|-----------|
# | Segmentasi       | Fokus pada lansia, mahasiswa, pensiunan            | Tinggi    |
# | Waktu Kampanye   | Maret, September, Oktober, Desember                | Tinggi    |
# | Kontak           | 1–5 kali, durasi 200–644 detik                     | Tinggi    |
# | Ekonomi          | Pantau `euribor3m` dan `nr.employed`              | Sedang    |
# | Pendidikan       | Edukasi berbasis data ekonomi                     | Sedang    |
# | Riwayat Kontak   | Prioritaskan `poutcome = nonexistent`              | Tinggi    |
#
# ---
#
# ## **Rekomendasi Implementasi Machine Learning**
#
# ### **Pengembangan Model Berkelanjutan**
#
# Model machine learning yang dikembangkan dalam proyek ini sebaiknya tidak dianggap sebagai solusi statis, melainkan sebagai fondasi untuk sistem prediksi yang terus berkembang. Perubahan dalam perilaku konsumen, kondisi ekonomi, dan regulasi perbankan dapat mempengaruhi performa model secara signifikan. Oleh karena itu, implementasi sistem monitoring yang robust menjadi sangat penting.
#
# Saya merekomendasikan untuk menetapkan jadwal regular untuk retraining model, idealnya setiap 3-6 bulan, tergantung pada volume data baru yang tersedia. Proses retraining ini harus mencakup validasi terhadap data terbaru dan penyesuaian hyperparameter jika diperlukan. Selain itu, implementasi sistem alert untuk mendeteksi drift dalam performa model akan membantu tim teknis untuk merespons perubahan dengan cepat.
#
# ### **Integrasi dengan Sistem Operasional**
#
# Keberhasilan implementasi machine learning dalam konteks bisnis tidak hanya bergantung pada akurasi model, tetapi juga pada kemudahan integrasi dengan sistem yang sudah ada. Model yang dikembangkan perlu diintegrasikan dengan sistem CRM bank untuk memungkinkan scoring real-time saat nasabah dihubungi.
#
# Saya menyarankan untuk mengembangkan API yang dapat diakses oleh sistem operasional, dengan mempertimbangkan aspek keamanan dan skalabilitas. API ini harus mampu menangani request scoring dalam waktu yang cepat (idealnya di bawah 1 detik) untuk memastikan pengalaman pengguna yang optimal. Selain itu, implementasi caching mechanism akan membantu mengurangi beban komputasi dan meningkatkan responsivitas sistem.
#
# ### **Monitoring dan Evaluasi**
#
# Sistem monitoring yang komprehensif perlu dibangun untuk memastikan model berfungsi sesuai dengan ekspektasi dalam lingkungan produksi. Monitoring ini harus mencakup tidak hanya metrik performa model, tetapi juga aspek teknis seperti latency, throughput, dan error rate.
#
# Saya merekomendasikan implementasi dashboard yang menampilkan metrik kunci seperti conversion rate, false positive rate, dan business impact dalam format yang mudah dipahami oleh stakeholder non-teknis. Dashboard ini akan memungkinkan tim bisnis untuk memantau performa kampanye secara real-time dan membuat keputusan yang informed.
#
# ### **Pengembangan Tim dan Kapabilitas**
#
# Implementasi machine learning yang sukses memerlukan tim yang memiliki pemahaman yang baik tentang aspek teknis maupun bisnis. Saya menyarankan untuk menginvestasikan waktu dan sumber daya dalam pengembangan kapabilitas tim, baik melalui training formal maupun knowledge sharing sessions.
#
# Tim data science perlu memiliki pemahaman yang mendalam tentang domain perbankan, sementara tim bisnis perlu memahami keterbatasan dan potensi machine learning. Kolaborasi yang erat antara kedua tim akan memastikan bahwa solusi yang dikembangkan tidak hanya secara teknis sound, tetapi juga relevan secara bisnis.
#
# ### **Ekspansi dan Pengembangan**
#
# Model yang dikembangkan untuk prediksi term deposit dapat menjadi fondasi untuk pengembangan solusi machine learning lainnya dalam domain perbankan. Saya melihat potensi untuk mengembangkan model serupa untuk produk-produk lain seperti kredit, asuransi, atau wealth management.
#
# Selain itu, implementasi teknik advanced seperti ensemble methods, deep learning, atau reinforcement learning dapat dipertimbangkan untuk meningkatkan performa model lebih lanjut. Namun, setiap peningkatan ini harus dibarengi dengan validasi yang ketat dan pertimbangan terhadap kompleksitas implementasi.
#
# ---
#
# ## **Kesimpulan Akhir**
#
# Implementasi machine learning dalam kampanye pemasaran bank ini telah membuktikan bahwa pendekatan data-driven dapat memberikan hasil yang luar biasa dalam konteks bisnis yang kompleks. Model yang dikembangkan tidak hanya berhasil meningkatkan efisiensi operasional, tetapi juga memberikan insight yang berharga untuk pengambilan keputusan strategis.
#
# Keberhasilan proyek ini menunjukkan pentingnya kolaborasi antara aspek teknis dan bisnis dalam pengembangan solusi machine learning. Pendekatan yang sistematis dalam pengembangan model, dari data preprocessing hingga deployment, telah menghasilkan solusi yang robust dan scalable.
#
# Masa depan implementasi machine learning dalam industri perbankan sangat menjanjikan. Dengan terus berkembangnya teknologi dan meningkatnya ketersediaan data, peluang untuk mengembangkan solusi yang lebih sophisticated dan impactful akan terus bertambah. Namun, kunci keberhasilan tetap terletak pada pemahaman yang mendalam tentang domain bisnis dan kemampuan untuk menerjemahkan insight teknis menjadi aksi bisnis yang konkret.

# %%
import pickle

with open("model.sav", "wb") as f:
    pickle.dump(final_model, f)

print("✅ Model berhasil disimpan ke 'model.sav'")
# Out:
# ✅ Model berhasil disimpan ke 'model.sav'
